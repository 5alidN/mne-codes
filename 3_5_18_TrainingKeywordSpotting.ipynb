# %% [markdown]
# <a href="https://colab.research.google.com/github/5alidN/mne-codes/blob/main/3_5_18_TrainingKeywordSpotting.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Training Keyword Spotting
# This notebook builds on the Colab in which we used the pre-trained [micro_speech](https://github.com/tensorflow/tensorflow/tree/v2.4.1/tensorflow/lite/micro/examples/micro_speech) example.
#
# **It is now time for you to train your own custom keyword spotting model using the Speech Commands dataset!**

# %% [markdown]
# #Setup

# %% [markdown]
# ## Import packages
# Clone the TensorFlow Github Repository, which contains the relevant code required to run this assignment.

# %%
import subprocess
import tensorflow as tf
import numpy as np

# Desired versions
tf_version = "2.19.0"
hub_version = "0.16.1"
datasets_version = "4.9.9"
numpy_version = "2.0.2"
protobuf_version = "4.25.3"

# Try importing optional packages
try:
    import tensorflow_hub as hub
except ImportError:
    hub = None

try:
    import tensorflow_datasets as tfds
except ImportError:
    tfds = None

# Helper to install a specific version of a package
def install_package(package, version):
    subprocess.check_call(["pip", "install", f"{package}=={version}"])

# Helper to uninstall multiple packages
def uninstall_packages(packages):
    subprocess.check_call(["pip", "uninstall", "-y"] + packages)

# Version mismatch check
version_mismatch = (
    tf.__version__ != tf_version or
    (hub and hub.__version__ != hub_version) or
    (tfds and tfds.__version__ != datasets_version) or
    not np.__version__.startswith(numpy_version)
)

# Act on mismatches
if version_mismatch:
    print(f"TensorFlow: {tf.__version__} → {tf_version}")
    if hub: print(f"TensorFlow Hub: {hub.__version__} → {hub_version}")
    if tfds: print(f"TensorFlow Datasets: {tfds.__version__} → {datasets_version}")
    print(f"NumPy: {np.__version__} → {numpy_version}")

    uninstall_packages([
        "tensorflow", "tensorflow_hub", "tensorflow_datasets",
        "numpy", "protobuf"
    ])

    install_package("tensorflow", tf_version)
    install_package("tensorflow_hub", hub_version)
    install_package("tensorflow_datasets", datasets_version)
    install_package("numpy", numpy_version)
    install_package("protobuf", protobuf_version)

    print("\n Required versions installed successfully.")
    print("Please restart the runtime (Runtime > Restart session) and re-run the notebook.")
else:
    print("All packages are already at the specified versions.")
# Out:
# All packages are already at the specified versions.

# %%
# !wget https://github.com/tensorflow/tensorflow/archive/v2.4.1.zip
# !unzip v2.4.1.zip &> 0
# !mv tensorflow-2.4.1/ tensorflow/
# Out:
# --2026-04-05 15:20:23--  https://github.com/tensorflow/tensorflow/archive/v2.4.1.zip
# Resolving github.com (github.com)... 140.82.113.3
# Connecting to github.com (github.com)|140.82.113.3|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://codeload.github.com/tensorflow/tensorflow/zip/refs/tags/v2.4.1 [following]
# --2026-04-05 15:20:23--  https://codeload.github.com/tensorflow/tensorflow/zip/refs/tags/v2.4.1
# Resolving codeload.github.com (codeload.github.com)... 140.82.112.10
# Connecting to codeload.github.com (codeload.github.com)|140.82.112.10|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [application/zip]
# Saving to: ‘v2.4.1.zip’
#
# v2.4.1.zip              [      <=>           ]  66.13M  13.1MB/s    in 5.7s
#
# 2026-04-05 15:20:29 (11.7 MB/s) - ‘v2.4.1.zip’ saved [69346072]

# %%
import tensorflow.compat.v1 as tf
#assert(tf.VERSION == "1.15.0") #Make sure you install Tensorflow 1.15.0 and restart the runtime or this will fail!
# Now that the runtime is set import things!
import sys
# We add this path so we can import the speech processing modules.
sys.path.append("/content/tensorflow/tensorflow/examples/speech_commands/")
import input_data
import models
import numpy as np
import pickle

# %% [markdown]
# ## Configure Your Model!
# Select your keywords and model settings with which to train!
#
# **This is where you need to make choices and input data!**
#
# ```WANTED_WORDS``` = A comma-delimited string of the words you want to train for (e.g., "yes,no"). All the other words you do not select will be used to train an "unknown" label so that the model does not just recognize speech but your specific words. Audio data with no spoken words will be used to train a "silence" label. We suggest picking 2-4 words for best results.
#
# Options for target words are (PICK FROM THIS LIST FOR BEST RESULTS): "one", "two", "three", "four", "five", "six", "seven", "eight", "nine",  "yes", "no", "up", "down", "left", "right", "on", "off", "stop", "go", “backward”, “forward”, “follow”, “learn”,
#
# Additional words that will be used to help train the "unkown" label are: "bed", "bird", "cat", "dog", "happy", "house", "marvin", "sheila", "tree", "wow"

# %%
WANTED_WORDS = "yes,no"

# %% [markdown]
# The number of training steps and learning rates can be specified as comma-separated strings to define the amount/rate at each stage. For example, ```TRAINING_STEPS="12000,3000"``` and ```LEARNING_RATE="0.001,0.0001"``` will run 12,000 training steps with a rate of 0.001 followed by 3,000 final steps with a learning rate of 0.0001. These are good default values to work off of when you choose your values as the course staff has gotten this to work well with those values in the past!

# %%
TRAINING_STEPS = "12000,3000"

LEARNING_RATE = "0.001,0.0001"

# %% [markdown]
# We suggest you leave the ```MODEL_ARCHITECTURE``` as tiny_conv the first time but if you would like to do this again and explore additional models some options are: ```single_fc, conv, low_latency_conv, low_latency_svdf, tiny_embedding_conv```

# %%
MODEL_ARCHITECTURE = 'tiny_conv'

# %%
# Calculate the total number of steps, which is used to identify the checkpoint
# file name.
TOTAL_STEPS = str(sum(map(lambda string: int(string), TRAINING_STEPS.split(","))))

# Print the configuration to confirm it
print("Training these words: %s" % WANTED_WORDS)
print("Training steps in each stage: %s" % TRAINING_STEPS)
print("Learning rate in each stage: %s" % LEARNING_RATE)
print("Total number of training steps: %s" % TOTAL_STEPS)
# Out:
# Training these words: yes,no
# Training steps in each stage: 12000,3000
# Learning rate in each stage: 0.001,0.0001
# Total number of training steps: 15000

# %% [markdown]
# **DO NOT MODIFY** the following constants as they include filepaths used in this notebook and data that is shared during training and inference.

# %%
# Calculate the percentage of 'silence' and 'unknown' training samples required
# to ensure that we have equal number of samples for each label.
number_of_labels = WANTED_WORDS.count(',') + 1
number_of_total_labels = number_of_labels + 2 # for 'silence' and 'unknown' label
equal_percentage_of_training_samples = int(100.0/(number_of_total_labels))
SILENT_PERCENTAGE = equal_percentage_of_training_samples
UNKNOWN_PERCENTAGE = equal_percentage_of_training_samples

# Constants which are shared during training and inference
PREPROCESS = 'micro'
WINDOW_STRIDE = 20

# Constants used during training only
VERBOSITY = 'DEBUG'
EVAL_STEP_INTERVAL = '1000'
SAVE_STEP_INTERVAL = '1000'

# Constants for training directories and filepaths
DATASET_DIR =  'dataset/'
LOGS_DIR = 'logs/'
TRAIN_DIR = 'train/' # for training checkpoints and other files.

# Constants for inference directories and filepaths
import os
MODELS_DIR = 'models'
if not os.path.exists(MODELS_DIR):
  os.mkdir(MODELS_DIR)
MODEL_TF = os.path.join(MODELS_DIR, 'model.pb')
MODEL_TFLITE = os.path.join(MODELS_DIR, 'model.tflite')
FLOAT_MODEL_TFLITE = os.path.join(MODELS_DIR, 'float_model.tflite')
MODEL_TFLITE_MICRO = os.path.join(MODELS_DIR, 'model.cc')
SAVED_MODEL = os.path.join(MODELS_DIR, 'saved_model')

# Constants for Quantization
QUANT_INPUT_MIN = 0.0
QUANT_INPUT_MAX = 26.0
QUANT_INPUT_RANGE = QUANT_INPUT_MAX - QUANT_INPUT_MIN

# Constants for audio process during Quantization and Evaluation
SAMPLE_RATE = 16000
CLIP_DURATION_MS = 1000
WINDOW_SIZE_MS = 30.0
FEATURE_BIN_COUNT = 40
BACKGROUND_FREQUENCY = 0.8
BACKGROUND_VOLUME_RANGE = 0.1
TIME_SHIFT_MS = 100.0

# URL for the dataset and train/val/test split
DATA_URL = 'https://storage.googleapis.com/download.tensorflow.org/data/speech_commands_v0.02.tar.gz'
VALIDATION_PERCENTAGE = 10
TESTING_PERCENTAGE = 10

# %%
# Calculate the correct flattened input data shape for later use in model conversion
# since the model takes a flattened version of the spectrogram. The shape is number of
# overlapping windows times the number of frequency bins. For the default settings we have
# 40 bins (as set above) times 49 windows (as calculated below) so the shape is (1,1960)
def window_counter(total_samples, window_size, stride):
  '''helper function to count the number of full-length overlapping windows'''
  window_count = 0
  sample_index = 0
  while True:
    window = range(sample_index,sample_index+stride)
    if window.stop < total_samples:
      window_count += 1
    else:
      break

    sample_index += stride
  return window_count

OVERLAPPING_WINDOWS = window_counter(CLIP_DURATION_MS, int(WINDOW_SIZE_MS), WINDOW_STRIDE)
FLATTENED_SPECTROGRAM_SHAPE = (1, OVERLAPPING_WINDOWS * FEATURE_BIN_COUNT)

# %% [markdown]
# # Train the model

# %% [markdown]
# ### Load in TensorBoard to visulaize the training process.
#
# As training progresses you should see the training status show up in the Tensorboard area. If this works it is very helpful for analyzing your training progress. Unfortunately, the staff has found that it sometimes doesn't start showing data for a while (~15 minutes) and sometimes doesn't show data until training completes (and instead shows ```No dashboards are active for the current data set```.). If it is working and then stops updating look to the top of the cell and click reconnect.

# %%
# %load_ext tensorboard
# %tensorboard --logdir {LOGS_DIR}

# %% [markdown]
# ### Launch Training
#
# **ARE YOU USING A GPU INSTANCE!?!?!**
# Make sure to check ```runtime->change runtime type``` as a GPU runtime will take ~2 hours to complete training whereas a CPU runtime with take ~10 hours!
#
# **Importantly, every hour or so you should make sure to remind colab you are still there by clicking around in a cell or clicking reconnect on the tensorboard cell (after 90 minutes of no activity Colab may kill the instance)!** But/and beyond that you can absolutely minimize the window and continue with other work.
#
# **If you run training a second time** we suggest restarting your runtime ```runtime->restart runtime``` in order to ensure all caches are cleared. However, do note that doing so will clear all cells and so you will have to run the entire file again.
#
# If you would like to get more information on the training script you can find the source code for the script [here](https://github.com/tensorflow/tensorflow/blob/master/tensorflow/examples/speech_commands/train.py). In short it sets up the optimizer and preprocessor based on all of the flags we pass in!
#
# Finally, by setting the ```VERBOSITY = 'DEBUG'``` above be aware that the training cell will print A LOT of information. Specifically you will get the accuracy and loss at each step as well as a confusion matrix every 1000 steps. We hope that is helpful in case TensorBoard fails to work. If you would like to run with less printouts you can change the setting to ```WARN``` or ```FATAL```. You will find this in the "Configure Your Model!" section.

# %%
# !python tensorflow/tensorflow/examples/speech_commands/train.py \
--data_dir={DATASET_DIR} \
--wanted_words={WANTED_WORDS} \
--silence_percentage={SILENT_PERCENTAGE} \
--unknown_percentage={UNKNOWN_PERCENTAGE} \
--preprocess={PREPROCESS} \
--window_stride={WINDOW_STRIDE} \
--model_architecture={MODEL_ARCHITECTURE} \
--how_many_training_steps={TRAINING_STEPS} \
--learning_rate={LEARNING_RATE} \
--train_dir={TRAIN_DIR} \
--summaries_dir={LOGS_DIR} \
--verbosity={VERBOSITY} \
--eval_step_interval={EVAL_STEP_INTERVAL} \
--save_step_interval={SAVE_STEP_INTERVAL}
# Out:
# Streaming output truncated to the last 5000 lines.
# DEBUG:tensorflow:Step #12532: rate 0.000100, accuracy 87.0%, cross entropy 0.354469
# I0405 16:47:59.808986 140544263226496 train.py:254] Step #12532: rate 0.000100, accuracy 87.0%, cross entropy 0.354469
# DEBUG:tensorflow:Step #12533: rate 0.000100, accuracy 90.0%, cross entropy 0.302899
# I0405 16:48:00.162378 140544263226496 train.py:254] Step #12533: rate 0.000100, accuracy 90.0%, cross entropy 0.302899
# DEBUG:tensorflow:Step #12534: rate 0.000100, accuracy 87.0%, cross entropy 0.284121
# I0405 16:48:00.506455 140544263226496 train.py:254] Step #12534: rate 0.000100, accuracy 87.0%, cross entropy 0.284121
# DEBUG:tensorflow:Step #12535: rate 0.000100, accuracy 85.0%, cross entropy 0.362831
# I0405 16:48:00.869355 140544263226496 train.py:254] Step #12535: rate 0.000100, accuracy 85.0%, cross entropy 0.362831
# DEBUG:tensorflow:Step #12536: rate 0.000100, accuracy 91.0%, cross entropy 0.282247
# I0405 16:48:01.219992 140544263226496 train.py:254] Step #12536: rate 0.000100, accuracy 91.0%, cross entropy 0.282247
# DEBUG:tensorflow:Step #12537: rate 0.000100, accuracy 82.0%, cross entropy 0.377750
# I0405 16:48:01.583169 140544263226496 train.py:254] Step #12537: rate 0.000100, accuracy 82.0%, cross entropy 0.377750
# DEBUG:tensorflow:Step #12538: rate 0.000100, accuracy 88.0%, cross entropy 0.312000
# I0405 16:48:01.958152 140544263226496 train.py:254] Step #12538: rate 0.000100, accuracy 88.0%, cross entropy 0.312000
# DEBUG:tensorflow:Step #12539: rate 0.000100, accuracy 90.0%, cross entropy 0.311156
# I0405 16:48:02.336649 140544263226496 train.py:254] Step #12539: rate 0.000100, accuracy 90.0%, cross entropy 0.311156
# DEBUG:tensorflow:Step #12540: rate 0.000100, accuracy 90.0%, cross entropy 0.232185
# I0405 16:48:02.712677 140544263226496 train.py:254] Step #12540: rate 0.000100, accuracy 90.0%, cross entropy 0.232185
# DEBUG:tensorflow:Step #12541: rate 0.000100, accuracy 90.0%, cross entropy 0.341675
# I0405 16:48:03.076919 140544263226496 train.py:254] Step #12541: rate 0.000100, accuracy 90.0%, cross entropy 0.341675
# DEBUG:tensorflow:Step #12542: rate 0.000100, accuracy 87.0%, cross entropy 0.370157
# I0405 16:48:03.445260 140544263226496 train.py:254] Step #12542: rate 0.000100, accuracy 87.0%, cross entropy 0.370157
# DEBUG:tensorflow:Step #12543: rate 0.000100, accuracy 86.0%, cross entropy 0.349632
# I0405 16:48:03.824645 140544263226496 train.py:254] Step #12543: rate 0.000100, accuracy 86.0%, cross entropy 0.349632
# DEBUG:tensorflow:Step #12544: rate 0.000100, accuracy 96.0%, cross entropy 0.185771
# I0405 16:48:04.181621 140544263226496 train.py:254] Step #12544: rate 0.000100, accuracy 96.0%, cross entropy 0.185771
# DEBUG:tensorflow:Step #12545: rate 0.000100, accuracy 92.0%, cross entropy 0.222712
# I0405 16:48:04.545799 140544263226496 train.py:254] Step #12545: rate 0.000100, accuracy 92.0%, cross entropy 0.222712
# DEBUG:tensorflow:Step #12546: rate 0.000100, accuracy 91.0%, cross entropy 0.281370
# I0405 16:48:04.927626 140544263226496 train.py:254] Step #12546: rate 0.000100, accuracy 91.0%, cross entropy 0.281370
# DEBUG:tensorflow:Step #12547: rate 0.000100, accuracy 89.0%, cross entropy 0.235756
# I0405 16:48:05.293618 140544263226496 train.py:254] Step #12547: rate 0.000100, accuracy 89.0%, cross entropy 0.235756
# DEBUG:tensorflow:Step #12548: rate 0.000100, accuracy 88.0%, cross entropy 0.244308
# I0405 16:48:05.649873 140544263226496 train.py:254] Step #12548: rate 0.000100, accuracy 88.0%, cross entropy 0.244308
# DEBUG:tensorflow:Step #12549: rate 0.000100, accuracy 92.0%, cross entropy 0.201652
# I0405 16:48:06.024916 140544263226496 train.py:254] Step #12549: rate 0.000100, accuracy 92.0%, cross entropy 0.201652
# DEBUG:tensorflow:Step #12550: rate 0.000100, accuracy 93.0%, cross entropy 0.183236
# I0405 16:48:06.378505 140544263226496 train.py:254] Step #12550: rate 0.000100, accuracy 93.0%, cross entropy 0.183236
# DEBUG:tensorflow:Step #12551: rate 0.000100, accuracy 95.0%, cross entropy 0.181065
# I0405 16:48:06.741370 140544263226496 train.py:254] Step #12551: rate 0.000100, accuracy 95.0%, cross entropy 0.181065
# DEBUG:tensorflow:Step #12552: rate 0.000100, accuracy 89.0%, cross entropy 0.357527
# I0405 16:48:07.120413 140544263226496 train.py:254] Step #12552: rate 0.000100, accuracy 89.0%, cross entropy 0.357527
# DEBUG:tensorflow:Step #12553: rate 0.000100, accuracy 91.0%, cross entropy 0.216208
# I0405 16:48:07.546287 140544263226496 train.py:254] Step #12553: rate 0.000100, accuracy 91.0%, cross entropy 0.216208
# DEBUG:tensorflow:Step #12554: rate 0.000100, accuracy 92.0%, cross entropy 0.227865
# I0405 16:48:08.096942 140544263226496 train.py:254] Step #12554: rate 0.000100, accuracy 92.0%, cross entropy 0.227865
# DEBUG:tensorflow:Step #12555: rate 0.000100, accuracy 86.0%, cross entropy 0.372649
# I0405 16:48:08.625575 140544263226496 train.py:254] Step #12555: rate 0.000100, accuracy 86.0%, cross entropy 0.372649
# DEBUG:tensorflow:Step #12556: rate 0.000100, accuracy 91.0%, cross entropy 0.233878
# I0405 16:48:09.164941 140544263226496 train.py:254] Step #12556: rate 0.000100, accuracy 91.0%, cross entropy 0.233878
# DEBUG:tensorflow:Step #12557: rate 0.000100, accuracy 88.0%, cross entropy 0.283226
# I0405 16:48:09.706596 140544263226496 train.py:254] Step #12557: rate 0.000100, accuracy 88.0%, cross entropy 0.283226
# DEBUG:tensorflow:Step #12558: rate 0.000100, accuracy 86.0%, cross entropy 0.333301
# I0405 16:48:10.255448 140544263226496 train.py:254] Step #12558: rate 0.000100, accuracy 86.0%, cross entropy 0.333301
# DEBUG:tensorflow:Step #12559: rate 0.000100, accuracy 91.0%, cross entropy 0.222993
# I0405 16:48:10.792945 140544263226496 train.py:254] Step #12559: rate 0.000100, accuracy 91.0%, cross entropy 0.222993
# DEBUG:tensorflow:Step #12560: rate 0.000100, accuracy 91.0%, cross entropy 0.225597
# I0405 16:48:11.160583 140544263226496 train.py:254] Step #12560: rate 0.000100, accuracy 91.0%, cross entropy 0.225597
# DEBUG:tensorflow:Step #12561: rate 0.000100, accuracy 91.0%, cross entropy 0.268863
# I0405 16:48:11.527463 140544263226496 train.py:254] Step #12561: rate 0.000100, accuracy 91.0%, cross entropy 0.268863
# DEBUG:tensorflow:Step #12562: rate 0.000100, accuracy 88.0%, cross entropy 0.330199
# I0405 16:48:11.894353 140544263226496 train.py:254] Step #12562: rate 0.000100, accuracy 88.0%, cross entropy 0.330199
# DEBUG:tensorflow:Step #12563: rate 0.000100, accuracy 91.0%, cross entropy 0.307522
# I0405 16:48:12.255290 140544263226496 train.py:254] Step #12563: rate 0.000100, accuracy 91.0%, cross entropy 0.307522
# DEBUG:tensorflow:Step #12564: rate 0.000100, accuracy 86.0%, cross entropy 0.297552
# I0405 16:48:12.612123 140544263226496 train.py:254] Step #12564: rate 0.000100, accuracy 86.0%, cross entropy 0.297552
# DEBUG:tensorflow:Step #12565: rate 0.000100, accuracy 94.0%, cross entropy 0.237801
# I0405 16:48:12.958436 140544263226496 train.py:254] Step #12565: rate 0.000100, accuracy 94.0%, cross entropy 0.237801
# DEBUG:tensorflow:Step #12566: rate 0.000100, accuracy 92.0%, cross entropy 0.265103
# I0405 16:48:13.343447 140544263226496 train.py:254] Step #12566: rate 0.000100, accuracy 92.0%, cross entropy 0.265103
# DEBUG:tensorflow:Step #12567: rate 0.000100, accuracy 90.0%, cross entropy 0.359294
# I0405 16:48:13.702852 140544263226496 train.py:254] Step #12567: rate 0.000100, accuracy 90.0%, cross entropy 0.359294
# DEBUG:tensorflow:Step #12568: rate 0.000100, accuracy 87.0%, cross entropy 0.405608
# I0405 16:48:14.057682 140544263226496 train.py:254] Step #12568: rate 0.000100, accuracy 87.0%, cross entropy 0.405608
# DEBUG:tensorflow:Step #12569: rate 0.000100, accuracy 86.0%, cross entropy 0.427378
# I0405 16:48:14.426611 140544263226496 train.py:254] Step #12569: rate 0.000100, accuracy 86.0%, cross entropy 0.427378
# DEBUG:tensorflow:Step #12570: rate 0.000100, accuracy 88.0%, cross entropy 0.377105
# I0405 16:48:14.806929 140544263226496 train.py:254] Step #12570: rate 0.000100, accuracy 88.0%, cross entropy 0.377105
# DEBUG:tensorflow:Step #12571: rate 0.000100, accuracy 88.0%, cross entropy 0.329119
# I0405 16:48:15.171008 140544263226496 train.py:254] Step #12571: rate 0.000100, accuracy 88.0%, cross entropy 0.329119
# DEBUG:tensorflow:Step #12572: rate 0.000100, accuracy 85.0%, cross entropy 0.421318
# I0405 16:48:15.539302 140544263226496 train.py:254] Step #12572: rate 0.000100, accuracy 85.0%, cross entropy 0.421318
# DEBUG:tensorflow:Step #12573: rate 0.000100, accuracy 93.0%, cross entropy 0.271264
# I0405 16:48:15.899839 140544263226496 train.py:254] Step #12573: rate 0.000100, accuracy 93.0%, cross entropy 0.271264
# DEBUG:tensorflow:Step #12574: rate 0.000100, accuracy 84.0%, cross entropy 0.400572
# I0405 16:48:16.262559 140544263226496 train.py:254] Step #12574: rate 0.000100, accuracy 84.0%, cross entropy 0.400572
# DEBUG:tensorflow:Step #12575: rate 0.000100, accuracy 93.0%, cross entropy 0.248064
# I0405 16:48:16.633596 140544263226496 train.py:254] Step #12575: rate 0.000100, accuracy 93.0%, cross entropy 0.248064
# DEBUG:tensorflow:Step #12576: rate 0.000100, accuracy 94.0%, cross entropy 0.179842
# I0405 16:48:16.987913 140544263226496 train.py:254] Step #12576: rate 0.000100, accuracy 94.0%, cross entropy 0.179842
# DEBUG:tensorflow:Step #12577: rate 0.000100, accuracy 90.0%, cross entropy 0.270984
# I0405 16:48:17.355085 140544263226496 train.py:254] Step #12577: rate 0.000100, accuracy 90.0%, cross entropy 0.270984
# DEBUG:tensorflow:Step #12578: rate 0.000100, accuracy 89.0%, cross entropy 0.303520
# I0405 16:48:17.721070 140544263226496 train.py:254] Step #12578: rate 0.000100, accuracy 89.0%, cross entropy 0.303520
# DEBUG:tensorflow:Step #12579: rate 0.000100, accuracy 91.0%, cross entropy 0.313024
# I0405 16:48:18.070266 140544263226496 train.py:254] Step #12579: rate 0.000100, accuracy 91.0%, cross entropy 0.313024
# DEBUG:tensorflow:Step #12580: rate 0.000100, accuracy 86.0%, cross entropy 0.409422
# I0405 16:48:18.432466 140544263226496 train.py:254] Step #12580: rate 0.000100, accuracy 86.0%, cross entropy 0.409422
# DEBUG:tensorflow:Step #12581: rate 0.000100, accuracy 82.0%, cross entropy 0.477516
# I0405 16:48:18.790474 140544263226496 train.py:254] Step #12581: rate 0.000100, accuracy 82.0%, cross entropy 0.477516
# DEBUG:tensorflow:Step #12582: rate 0.000100, accuracy 89.0%, cross entropy 0.309337
# I0405 16:48:19.144048 140544263226496 train.py:254] Step #12582: rate 0.000100, accuracy 89.0%, cross entropy 0.309337
# DEBUG:tensorflow:Step #12583: rate 0.000100, accuracy 92.0%, cross entropy 0.232138
# I0405 16:48:19.528728 140544263226496 train.py:254] Step #12583: rate 0.000100, accuracy 92.0%, cross entropy 0.232138
# DEBUG:tensorflow:Step #12584: rate 0.000100, accuracy 85.0%, cross entropy 0.373972
# I0405 16:48:19.896336 140544263226496 train.py:254] Step #12584: rate 0.000100, accuracy 85.0%, cross entropy 0.373972
# DEBUG:tensorflow:Step #12585: rate 0.000100, accuracy 88.0%, cross entropy 0.351710
# I0405 16:48:20.257147 140544263226496 train.py:254] Step #12585: rate 0.000100, accuracy 88.0%, cross entropy 0.351710
# DEBUG:tensorflow:Step #12586: rate 0.000100, accuracy 89.0%, cross entropy 0.294660
# I0405 16:48:20.637285 140544263226496 train.py:254] Step #12586: rate 0.000100, accuracy 89.0%, cross entropy 0.294660
# DEBUG:tensorflow:Step #12587: rate 0.000100, accuracy 85.0%, cross entropy 0.386198
# I0405 16:48:21.155728 140544263226496 train.py:254] Step #12587: rate 0.000100, accuracy 85.0%, cross entropy 0.386198
# DEBUG:tensorflow:Step #12588: rate 0.000100, accuracy 95.0%, cross entropy 0.198564
# I0405 16:48:21.718941 140544263226496 train.py:254] Step #12588: rate 0.000100, accuracy 95.0%, cross entropy 0.198564
# DEBUG:tensorflow:Step #12589: rate 0.000100, accuracy 89.0%, cross entropy 0.279931
# I0405 16:48:22.274914 140544263226496 train.py:254] Step #12589: rate 0.000100, accuracy 89.0%, cross entropy 0.279931
# DEBUG:tensorflow:Step #12590: rate 0.000100, accuracy 90.0%, cross entropy 0.318115
# I0405 16:48:22.834772 140544263226496 train.py:254] Step #12590: rate 0.000100, accuracy 90.0%, cross entropy 0.318115
# DEBUG:tensorflow:Step #12591: rate 0.000100, accuracy 89.0%, cross entropy 0.297313
# I0405 16:48:23.388791 140544263226496 train.py:254] Step #12591: rate 0.000100, accuracy 89.0%, cross entropy 0.297313
# DEBUG:tensorflow:Step #12592: rate 0.000100, accuracy 84.0%, cross entropy 0.519502
# I0405 16:48:23.931102 140544263226496 train.py:254] Step #12592: rate 0.000100, accuracy 84.0%, cross entropy 0.519502
# DEBUG:tensorflow:Step #12593: rate 0.000100, accuracy 86.0%, cross entropy 0.282073
# I0405 16:48:24.328604 140544263226496 train.py:254] Step #12593: rate 0.000100, accuracy 86.0%, cross entropy 0.282073
# DEBUG:tensorflow:Step #12594: rate 0.000100, accuracy 92.0%, cross entropy 0.259601
# I0405 16:48:24.685563 140544263226496 train.py:254] Step #12594: rate 0.000100, accuracy 92.0%, cross entropy 0.259601
# DEBUG:tensorflow:Step #12595: rate 0.000100, accuracy 83.0%, cross entropy 0.409549
# I0405 16:48:25.063707 140544263226496 train.py:254] Step #12595: rate 0.000100, accuracy 83.0%, cross entropy 0.409549
# DEBUG:tensorflow:Step #12596: rate 0.000100, accuracy 85.0%, cross entropy 0.369108
# I0405 16:48:25.418458 140544263226496 train.py:254] Step #12596: rate 0.000100, accuracy 85.0%, cross entropy 0.369108
# DEBUG:tensorflow:Step #12597: rate 0.000100, accuracy 95.0%, cross entropy 0.179959
# I0405 16:48:25.785128 140544263226496 train.py:254] Step #12597: rate 0.000100, accuracy 95.0%, cross entropy 0.179959
# DEBUG:tensorflow:Step #12598: rate 0.000100, accuracy 93.0%, cross entropy 0.201612
# I0405 16:48:26.160813 140544263226496 train.py:254] Step #12598: rate 0.000100, accuracy 93.0%, cross entropy 0.201612
# DEBUG:tensorflow:Step #12599: rate 0.000100, accuracy 91.0%, cross entropy 0.332116
# I0405 16:48:26.516455 140544263226496 train.py:254] Step #12599: rate 0.000100, accuracy 91.0%, cross entropy 0.332116
# DEBUG:tensorflow:Step #12600: rate 0.000100, accuracy 81.0%, cross entropy 0.451238
# I0405 16:48:26.886448 140544263226496 train.py:254] Step #12600: rate 0.000100, accuracy 81.0%, cross entropy 0.451238
# DEBUG:tensorflow:Step #12601: rate 0.000100, accuracy 87.0%, cross entropy 0.339732
# I0405 16:48:27.260958 140544263226496 train.py:254] Step #12601: rate 0.000100, accuracy 87.0%, cross entropy 0.339732
# DEBUG:tensorflow:Step #12602: rate 0.000100, accuracy 87.0%, cross entropy 0.302110
# I0405 16:48:27.621999 140544263226496 train.py:254] Step #12602: rate 0.000100, accuracy 87.0%, cross entropy 0.302110
# DEBUG:tensorflow:Step #12603: rate 0.000100, accuracy 89.0%, cross entropy 0.329767
# I0405 16:48:27.992303 140544263226496 train.py:254] Step #12603: rate 0.000100, accuracy 89.0%, cross entropy 0.329767
# DEBUG:tensorflow:Step #12604: rate 0.000100, accuracy 94.0%, cross entropy 0.260896
# I0405 16:48:28.357056 140544263226496 train.py:254] Step #12604: rate 0.000100, accuracy 94.0%, cross entropy 0.260896
# DEBUG:tensorflow:Step #12605: rate 0.000100, accuracy 90.0%, cross entropy 0.310407
# I0405 16:48:28.718979 140544263226496 train.py:254] Step #12605: rate 0.000100, accuracy 90.0%, cross entropy 0.310407
# DEBUG:tensorflow:Step #12606: rate 0.000100, accuracy 87.0%, cross entropy 0.316229
# I0405 16:48:29.104387 140544263226496 train.py:254] Step #12606: rate 0.000100, accuracy 87.0%, cross entropy 0.316229
# DEBUG:tensorflow:Step #12607: rate 0.000100, accuracy 89.0%, cross entropy 0.256923
# I0405 16:48:29.472946 140544263226496 train.py:254] Step #12607: rate 0.000100, accuracy 89.0%, cross entropy 0.256923
# DEBUG:tensorflow:Step #12608: rate 0.000100, accuracy 92.0%, cross entropy 0.206537
# I0405 16:48:29.838649 140544263226496 train.py:254] Step #12608: rate 0.000100, accuracy 92.0%, cross entropy 0.206537
# DEBUG:tensorflow:Step #12609: rate 0.000100, accuracy 88.0%, cross entropy 0.322137
# I0405 16:48:30.212492 140544263226496 train.py:254] Step #12609: rate 0.000100, accuracy 88.0%, cross entropy 0.322137
# DEBUG:tensorflow:Step #12610: rate 0.000100, accuracy 93.0%, cross entropy 0.195776
# I0405 16:48:30.568100 140544263226496 train.py:254] Step #12610: rate 0.000100, accuracy 93.0%, cross entropy 0.195776
# DEBUG:tensorflow:Step #12611: rate 0.000100, accuracy 89.0%, cross entropy 0.320758
# I0405 16:48:30.926616 140544263226496 train.py:254] Step #12611: rate 0.000100, accuracy 89.0%, cross entropy 0.320758
# DEBUG:tensorflow:Step #12612: rate 0.000100, accuracy 88.0%, cross entropy 0.295105
# I0405 16:48:31.303669 140544263226496 train.py:254] Step #12612: rate 0.000100, accuracy 88.0%, cross entropy 0.295105
# DEBUG:tensorflow:Step #12613: rate 0.000100, accuracy 88.0%, cross entropy 0.411642
# I0405 16:48:31.679825 140544263226496 train.py:254] Step #12613: rate 0.000100, accuracy 88.0%, cross entropy 0.411642
# DEBUG:tensorflow:Step #12614: rate 0.000100, accuracy 92.0%, cross entropy 0.277787
# I0405 16:48:32.033333 140544263226496 train.py:254] Step #12614: rate 0.000100, accuracy 92.0%, cross entropy 0.277787
# DEBUG:tensorflow:Step #12615: rate 0.000100, accuracy 93.0%, cross entropy 0.234414
# I0405 16:48:32.408738 140544263226496 train.py:254] Step #12615: rate 0.000100, accuracy 93.0%, cross entropy 0.234414
# DEBUG:tensorflow:Step #12616: rate 0.000100, accuracy 89.0%, cross entropy 0.231636
# I0405 16:48:32.767278 140544263226496 train.py:254] Step #12616: rate 0.000100, accuracy 89.0%, cross entropy 0.231636
# DEBUG:tensorflow:Step #12617: rate 0.000100, accuracy 90.0%, cross entropy 0.304262
# I0405 16:48:33.134106 140544263226496 train.py:254] Step #12617: rate 0.000100, accuracy 90.0%, cross entropy 0.304262
# DEBUG:tensorflow:Step #12618: rate 0.000100, accuracy 88.0%, cross entropy 0.359276
# I0405 16:48:33.504519 140544263226496 train.py:254] Step #12618: rate 0.000100, accuracy 88.0%, cross entropy 0.359276
# DEBUG:tensorflow:Step #12619: rate 0.000100, accuracy 90.0%, cross entropy 0.257937
# I0405 16:48:33.862895 140544263226496 train.py:254] Step #12619: rate 0.000100, accuracy 90.0%, cross entropy 0.257937
# DEBUG:tensorflow:Step #12620: rate 0.000100, accuracy 91.0%, cross entropy 0.328752
# I0405 16:48:34.320915 140544263226496 train.py:254] Step #12620: rate 0.000100, accuracy 91.0%, cross entropy 0.328752
# DEBUG:tensorflow:Step #12621: rate 0.000100, accuracy 88.0%, cross entropy 0.366829
# I0405 16:48:34.849034 140544263226496 train.py:254] Step #12621: rate 0.000100, accuracy 88.0%, cross entropy 0.366829
# DEBUG:tensorflow:Step #12622: rate 0.000100, accuracy 89.0%, cross entropy 0.283601
# I0405 16:48:35.397885 140544263226496 train.py:254] Step #12622: rate 0.000100, accuracy 89.0%, cross entropy 0.283601
# DEBUG:tensorflow:Step #12623: rate 0.000100, accuracy 86.0%, cross entropy 0.420407
# I0405 16:48:35.944488 140544263226496 train.py:254] Step #12623: rate 0.000100, accuracy 86.0%, cross entropy 0.420407
# DEBUG:tensorflow:Step #12624: rate 0.000100, accuracy 89.0%, cross entropy 0.261175
# I0405 16:48:36.509553 140544263226496 train.py:254] Step #12624: rate 0.000100, accuracy 89.0%, cross entropy 0.261175
# DEBUG:tensorflow:Step #12625: rate 0.000100, accuracy 89.0%, cross entropy 0.264291
# I0405 16:48:37.059914 140544263226496 train.py:254] Step #12625: rate 0.000100, accuracy 89.0%, cross entropy 0.264291
# DEBUG:tensorflow:Step #12626: rate 0.000100, accuracy 85.0%, cross entropy 0.359598
# I0405 16:48:37.510911 140544263226496 train.py:254] Step #12626: rate 0.000100, accuracy 85.0%, cross entropy 0.359598
# DEBUG:tensorflow:Step #12627: rate 0.000100, accuracy 90.0%, cross entropy 0.315919
# I0405 16:48:37.865526 140544263226496 train.py:254] Step #12627: rate 0.000100, accuracy 90.0%, cross entropy 0.315919
# DEBUG:tensorflow:Step #12628: rate 0.000100, accuracy 90.0%, cross entropy 0.262367
# I0405 16:48:38.220436 140544263226496 train.py:254] Step #12628: rate 0.000100, accuracy 90.0%, cross entropy 0.262367
# DEBUG:tensorflow:Step #12629: rate 0.000100, accuracy 93.0%, cross entropy 0.261111
# I0405 16:48:38.591151 140544263226496 train.py:254] Step #12629: rate 0.000100, accuracy 93.0%, cross entropy 0.261111
# DEBUG:tensorflow:Step #12630: rate 0.000100, accuracy 91.0%, cross entropy 0.306411
# I0405 16:48:38.950376 140544263226496 train.py:254] Step #12630: rate 0.000100, accuracy 91.0%, cross entropy 0.306411
# DEBUG:tensorflow:Step #12631: rate 0.000100, accuracy 89.0%, cross entropy 0.327739
# I0405 16:48:39.311520 140544263226496 train.py:254] Step #12631: rate 0.000100, accuracy 89.0%, cross entropy 0.327739
# DEBUG:tensorflow:Step #12632: rate 0.000100, accuracy 88.0%, cross entropy 0.261219
# I0405 16:48:39.723631 140544263226496 train.py:254] Step #12632: rate 0.000100, accuracy 88.0%, cross entropy 0.261219
# DEBUG:tensorflow:Step #12633: rate 0.000100, accuracy 87.0%, cross entropy 0.331681
# I0405 16:48:40.084663 140544263226496 train.py:254] Step #12633: rate 0.000100, accuracy 87.0%, cross entropy 0.331681
# DEBUG:tensorflow:Step #12634: rate 0.000100, accuracy 81.0%, cross entropy 0.446609
# I0405 16:48:40.449645 140544263226496 train.py:254] Step #12634: rate 0.000100, accuracy 81.0%, cross entropy 0.446609
# DEBUG:tensorflow:Step #12635: rate 0.000100, accuracy 90.0%, cross entropy 0.274193
# I0405 16:48:40.826832 140544263226496 train.py:254] Step #12635: rate 0.000100, accuracy 90.0%, cross entropy 0.274193
# DEBUG:tensorflow:Step #12636: rate 0.000100, accuracy 82.0%, cross entropy 0.447545
# I0405 16:48:41.196250 140544263226496 train.py:254] Step #12636: rate 0.000100, accuracy 82.0%, cross entropy 0.447545
# DEBUG:tensorflow:Step #12637: rate 0.000100, accuracy 90.0%, cross entropy 0.314767
# I0405 16:48:41.570690 140544263226496 train.py:254] Step #12637: rate 0.000100, accuracy 90.0%, cross entropy 0.314767
# DEBUG:tensorflow:Step #12638: rate 0.000100, accuracy 89.0%, cross entropy 0.337909
# I0405 16:48:41.945957 140544263226496 train.py:254] Step #12638: rate 0.000100, accuracy 89.0%, cross entropy 0.337909
# DEBUG:tensorflow:Step #12639: rate 0.000100, accuracy 87.0%, cross entropy 0.351035
# I0405 16:48:42.329088 140544263226496 train.py:254] Step #12639: rate 0.000100, accuracy 87.0%, cross entropy 0.351035
# DEBUG:tensorflow:Step #12640: rate 0.000100, accuracy 84.0%, cross entropy 0.326906
# I0405 16:48:42.708738 140544263226496 train.py:254] Step #12640: rate 0.000100, accuracy 84.0%, cross entropy 0.326906
# DEBUG:tensorflow:Step #12641: rate 0.000100, accuracy 93.0%, cross entropy 0.200783
# I0405 16:48:43.073460 140544263226496 train.py:254] Step #12641: rate 0.000100, accuracy 93.0%, cross entropy 0.200783
# DEBUG:tensorflow:Step #12642: rate 0.000100, accuracy 93.0%, cross entropy 0.237527
# I0405 16:48:43.431412 140544263226496 train.py:254] Step #12642: rate 0.000100, accuracy 93.0%, cross entropy 0.237527
# DEBUG:tensorflow:Step #12643: rate 0.000100, accuracy 91.0%, cross entropy 0.320267
# I0405 16:48:43.817546 140544263226496 train.py:254] Step #12643: rate 0.000100, accuracy 91.0%, cross entropy 0.320267
# DEBUG:tensorflow:Step #12644: rate 0.000100, accuracy 89.0%, cross entropy 0.317831
# I0405 16:48:44.180850 140544263226496 train.py:254] Step #12644: rate 0.000100, accuracy 89.0%, cross entropy 0.317831
# DEBUG:tensorflow:Step #12645: rate 0.000100, accuracy 86.0%, cross entropy 0.325118
# I0405 16:48:44.546448 140544263226496 train.py:254] Step #12645: rate 0.000100, accuracy 86.0%, cross entropy 0.325118
# DEBUG:tensorflow:Step #12646: rate 0.000100, accuracy 91.0%, cross entropy 0.239343
# I0405 16:48:44.922068 140544263226496 train.py:254] Step #12646: rate 0.000100, accuracy 91.0%, cross entropy 0.239343
# DEBUG:tensorflow:Step #12647: rate 0.000100, accuracy 90.0%, cross entropy 0.272298
# I0405 16:48:45.280526 140544263226496 train.py:254] Step #12647: rate 0.000100, accuracy 90.0%, cross entropy 0.272298
# DEBUG:tensorflow:Step #12648: rate 0.000100, accuracy 91.0%, cross entropy 0.303241
# I0405 16:48:45.640196 140544263226496 train.py:254] Step #12648: rate 0.000100, accuracy 91.0%, cross entropy 0.303241
# DEBUG:tensorflow:Step #12649: rate 0.000100, accuracy 88.0%, cross entropy 0.303658
# I0405 16:48:46.009906 140544263226496 train.py:254] Step #12649: rate 0.000100, accuracy 88.0%, cross entropy 0.303658
# DEBUG:tensorflow:Step #12650: rate 0.000100, accuracy 88.0%, cross entropy 0.360684
# I0405 16:48:46.361739 140544263226496 train.py:254] Step #12650: rate 0.000100, accuracy 88.0%, cross entropy 0.360684
# DEBUG:tensorflow:Step #12651: rate 0.000100, accuracy 86.0%, cross entropy 0.392085
# I0405 16:48:46.731912 140544263226496 train.py:254] Step #12651: rate 0.000100, accuracy 86.0%, cross entropy 0.392085
# DEBUG:tensorflow:Step #12652: rate 0.000100, accuracy 89.0%, cross entropy 0.229676
# I0405 16:48:47.102414 140544263226496 train.py:254] Step #12652: rate 0.000100, accuracy 89.0%, cross entropy 0.229676
# DEBUG:tensorflow:Step #12653: rate 0.000100, accuracy 97.0%, cross entropy 0.155152
# I0405 16:48:47.564053 140544263226496 train.py:254] Step #12653: rate 0.000100, accuracy 97.0%, cross entropy 0.155152
# DEBUG:tensorflow:Step #12654: rate 0.000100, accuracy 90.0%, cross entropy 0.236108
# I0405 16:48:48.118019 140544263226496 train.py:254] Step #12654: rate 0.000100, accuracy 90.0%, cross entropy 0.236108
# DEBUG:tensorflow:Step #12655: rate 0.000100, accuracy 92.0%, cross entropy 0.196238
# I0405 16:48:48.672235 140544263226496 train.py:254] Step #12655: rate 0.000100, accuracy 92.0%, cross entropy 0.196238
# DEBUG:tensorflow:Step #12656: rate 0.000100, accuracy 88.0%, cross entropy 0.311061
# I0405 16:48:49.239549 140544263226496 train.py:254] Step #12656: rate 0.000100, accuracy 88.0%, cross entropy 0.311061
# DEBUG:tensorflow:Step #12657: rate 0.000100, accuracy 86.0%, cross entropy 0.433963
# I0405 16:48:49.790420 140544263226496 train.py:254] Step #12657: rate 0.000100, accuracy 86.0%, cross entropy 0.433963
# DEBUG:tensorflow:Step #12658: rate 0.000100, accuracy 94.0%, cross entropy 0.179610
# I0405 16:48:50.347618 140544263226496 train.py:254] Step #12658: rate 0.000100, accuracy 94.0%, cross entropy 0.179610
# DEBUG:tensorflow:Step #12659: rate 0.000100, accuracy 88.0%, cross entropy 0.299337
# I0405 16:48:50.831891 140544263226496 train.py:254] Step #12659: rate 0.000100, accuracy 88.0%, cross entropy 0.299337
# DEBUG:tensorflow:Step #12660: rate 0.000100, accuracy 90.0%, cross entropy 0.295990
# I0405 16:48:51.212532 140544263226496 train.py:254] Step #12660: rate 0.000100, accuracy 90.0%, cross entropy 0.295990
# DEBUG:tensorflow:Step #12661: rate 0.000100, accuracy 90.0%, cross entropy 0.290193
# I0405 16:48:51.581484 140544263226496 train.py:254] Step #12661: rate 0.000100, accuracy 90.0%, cross entropy 0.290193
# DEBUG:tensorflow:Step #12662: rate 0.000100, accuracy 91.0%, cross entropy 0.239438
# I0405 16:48:51.935503 140544263226496 train.py:254] Step #12662: rate 0.000100, accuracy 91.0%, cross entropy 0.239438
# DEBUG:tensorflow:Step #12663: rate 0.000100, accuracy 91.0%, cross entropy 0.205831
# I0405 16:48:52.311973 140544263226496 train.py:254] Step #12663: rate 0.000100, accuracy 91.0%, cross entropy 0.205831
# DEBUG:tensorflow:Step #12664: rate 0.000100, accuracy 93.0%, cross entropy 0.174199
# I0405 16:48:52.687387 140544263226496 train.py:254] Step #12664: rate 0.000100, accuracy 93.0%, cross entropy 0.174199
# DEBUG:tensorflow:Step #12665: rate 0.000100, accuracy 89.0%, cross entropy 0.319116
# I0405 16:48:53.044721 140544263226496 train.py:254] Step #12665: rate 0.000100, accuracy 89.0%, cross entropy 0.319116
# DEBUG:tensorflow:Step #12666: rate 0.000100, accuracy 91.0%, cross entropy 0.296035
# I0405 16:48:53.435376 140544263226496 train.py:254] Step #12666: rate 0.000100, accuracy 91.0%, cross entropy 0.296035
# DEBUG:tensorflow:Step #12667: rate 0.000100, accuracy 89.0%, cross entropy 0.346686
# I0405 16:48:53.790976 140544263226496 train.py:254] Step #12667: rate 0.000100, accuracy 89.0%, cross entropy 0.346686
# DEBUG:tensorflow:Step #12668: rate 0.000100, accuracy 89.0%, cross entropy 0.278408
# I0405 16:48:54.146428 140544263226496 train.py:254] Step #12668: rate 0.000100, accuracy 89.0%, cross entropy 0.278408
# DEBUG:tensorflow:Step #12669: rate 0.000100, accuracy 85.0%, cross entropy 0.432440
# I0405 16:48:54.521411 140544263226496 train.py:254] Step #12669: rate 0.000100, accuracy 85.0%, cross entropy 0.432440
# DEBUG:tensorflow:Step #12670: rate 0.000100, accuracy 93.0%, cross entropy 0.211532
# I0405 16:48:54.881719 140544263226496 train.py:254] Step #12670: rate 0.000100, accuracy 93.0%, cross entropy 0.211532
# DEBUG:tensorflow:Step #12671: rate 0.000100, accuracy 91.0%, cross entropy 0.195596
# I0405 16:48:55.259030 140544263226496 train.py:254] Step #12671: rate 0.000100, accuracy 91.0%, cross entropy 0.195596
# DEBUG:tensorflow:Step #12672: rate 0.000100, accuracy 95.0%, cross entropy 0.225373
# I0405 16:48:55.617259 140544263226496 train.py:254] Step #12672: rate 0.000100, accuracy 95.0%, cross entropy 0.225373
# DEBUG:tensorflow:Step #12673: rate 0.000100, accuracy 91.0%, cross entropy 0.228985
# I0405 16:48:55.980502 140544263226496 train.py:254] Step #12673: rate 0.000100, accuracy 91.0%, cross entropy 0.228985
# DEBUG:tensorflow:Step #12674: rate 0.000100, accuracy 88.0%, cross entropy 0.293986
# I0405 16:48:56.345367 140544263226496 train.py:254] Step #12674: rate 0.000100, accuracy 88.0%, cross entropy 0.293986
# DEBUG:tensorflow:Step #12675: rate 0.000100, accuracy 85.0%, cross entropy 0.345738
# I0405 16:48:56.702397 140544263226496 train.py:254] Step #12675: rate 0.000100, accuracy 85.0%, cross entropy 0.345738
# DEBUG:tensorflow:Step #12676: rate 0.000100, accuracy 90.0%, cross entropy 0.379158
# I0405 16:48:57.059613 140544263226496 train.py:254] Step #12676: rate 0.000100, accuracy 90.0%, cross entropy 0.379158
# DEBUG:tensorflow:Step #12677: rate 0.000100, accuracy 96.0%, cross entropy 0.156139
# I0405 16:48:57.439687 140544263226496 train.py:254] Step #12677: rate 0.000100, accuracy 96.0%, cross entropy 0.156139
# DEBUG:tensorflow:Step #12678: rate 0.000100, accuracy 90.0%, cross entropy 0.337268
# I0405 16:48:57.803600 140544263226496 train.py:254] Step #12678: rate 0.000100, accuracy 90.0%, cross entropy 0.337268
# DEBUG:tensorflow:Step #12679: rate 0.000100, accuracy 91.0%, cross entropy 0.266753
# I0405 16:48:58.166700 140544263226496 train.py:254] Step #12679: rate 0.000100, accuracy 91.0%, cross entropy 0.266753
# DEBUG:tensorflow:Step #12680: rate 0.000100, accuracy 89.0%, cross entropy 0.236581
# I0405 16:48:58.537314 140544263226496 train.py:254] Step #12680: rate 0.000100, accuracy 89.0%, cross entropy 0.236581
# DEBUG:tensorflow:Step #12681: rate 0.000100, accuracy 87.0%, cross entropy 0.336312
# I0405 16:48:58.902684 140544263226496 train.py:254] Step #12681: rate 0.000100, accuracy 87.0%, cross entropy 0.336312
# DEBUG:tensorflow:Step #12682: rate 0.000100, accuracy 83.0%, cross entropy 0.456737
# I0405 16:48:59.254272 140544263226496 train.py:254] Step #12682: rate 0.000100, accuracy 83.0%, cross entropy 0.456737
# DEBUG:tensorflow:Step #12683: rate 0.000100, accuracy 92.0%, cross entropy 0.216387
# I0405 16:48:59.607675 140544263226496 train.py:254] Step #12683: rate 0.000100, accuracy 92.0%, cross entropy 0.216387
# DEBUG:tensorflow:Step #12684: rate 0.000100, accuracy 84.0%, cross entropy 0.440633
# I0405 16:48:59.956864 140544263226496 train.py:254] Step #12684: rate 0.000100, accuracy 84.0%, cross entropy 0.440633
# DEBUG:tensorflow:Step #12685: rate 0.000100, accuracy 87.0%, cross entropy 0.328748
# I0405 16:49:00.301489 140544263226496 train.py:254] Step #12685: rate 0.000100, accuracy 87.0%, cross entropy 0.328748
# DEBUG:tensorflow:Step #12686: rate 0.000100, accuracy 90.0%, cross entropy 0.372308
# I0405 16:49:00.664347 140544263226496 train.py:254] Step #12686: rate 0.000100, accuracy 90.0%, cross entropy 0.372308
# DEBUG:tensorflow:Step #12687: rate 0.000100, accuracy 95.0%, cross entropy 0.182039
# I0405 16:49:01.194847 140544263226496 train.py:254] Step #12687: rate 0.000100, accuracy 95.0%, cross entropy 0.182039
# DEBUG:tensorflow:Step #12688: rate 0.000100, accuracy 95.0%, cross entropy 0.195623
# I0405 16:49:01.737765 140544263226496 train.py:254] Step #12688: rate 0.000100, accuracy 95.0%, cross entropy 0.195623
# DEBUG:tensorflow:Step #12689: rate 0.000100, accuracy 91.0%, cross entropy 0.275880
# I0405 16:49:02.273618 140544263226496 train.py:254] Step #12689: rate 0.000100, accuracy 91.0%, cross entropy 0.275880
# DEBUG:tensorflow:Step #12690: rate 0.000100, accuracy 89.0%, cross entropy 0.338137
# I0405 16:49:02.839698 140544263226496 train.py:254] Step #12690: rate 0.000100, accuracy 89.0%, cross entropy 0.338137
# DEBUG:tensorflow:Step #12691: rate 0.000100, accuracy 88.0%, cross entropy 0.363776
# I0405 16:49:03.374428 140544263226496 train.py:254] Step #12691: rate 0.000100, accuracy 88.0%, cross entropy 0.363776
# DEBUG:tensorflow:Step #12692: rate 0.000100, accuracy 90.0%, cross entropy 0.256215
# I0405 16:49:03.919947 140544263226496 train.py:254] Step #12692: rate 0.000100, accuracy 90.0%, cross entropy 0.256215
# DEBUG:tensorflow:Step #12693: rate 0.000100, accuracy 86.0%, cross entropy 0.431291
# I0405 16:49:04.297481 140544263226496 train.py:254] Step #12693: rate 0.000100, accuracy 86.0%, cross entropy 0.431291
# DEBUG:tensorflow:Step #12694: rate 0.000100, accuracy 86.0%, cross entropy 0.370315
# I0405 16:49:04.653511 140544263226496 train.py:254] Step #12694: rate 0.000100, accuracy 86.0%, cross entropy 0.370315
# DEBUG:tensorflow:Step #12695: rate 0.000100, accuracy 89.0%, cross entropy 0.300849
# I0405 16:49:05.030890 140544263226496 train.py:254] Step #12695: rate 0.000100, accuracy 89.0%, cross entropy 0.300849
# DEBUG:tensorflow:Step #12696: rate 0.000100, accuracy 87.0%, cross entropy 0.259697
# I0405 16:49:05.401771 140544263226496 train.py:254] Step #12696: rate 0.000100, accuracy 87.0%, cross entropy 0.259697
# DEBUG:tensorflow:Step #12697: rate 0.000100, accuracy 86.0%, cross entropy 0.427820
# I0405 16:49:05.770506 140544263226496 train.py:254] Step #12697: rate 0.000100, accuracy 86.0%, cross entropy 0.427820
# DEBUG:tensorflow:Step #12698: rate 0.000100, accuracy 88.0%, cross entropy 0.391589
# I0405 16:49:06.129934 140544263226496 train.py:254] Step #12698: rate 0.000100, accuracy 88.0%, cross entropy 0.391589
# DEBUG:tensorflow:Step #12699: rate 0.000100, accuracy 92.0%, cross entropy 0.290280
# I0405 16:49:06.487209 140544263226496 train.py:254] Step #12699: rate 0.000100, accuracy 92.0%, cross entropy 0.290280
# DEBUG:tensorflow:Step #12700: rate 0.000100, accuracy 87.0%, cross entropy 0.363541
# I0405 16:49:06.864382 140544263226496 train.py:254] Step #12700: rate 0.000100, accuracy 87.0%, cross entropy 0.363541
# DEBUG:tensorflow:Step #12701: rate 0.000100, accuracy 88.0%, cross entropy 0.380177
# I0405 16:49:07.217009 140544263226496 train.py:254] Step #12701: rate 0.000100, accuracy 88.0%, cross entropy 0.380177
# DEBUG:tensorflow:Step #12702: rate 0.000100, accuracy 88.0%, cross entropy 0.355039
# I0405 16:49:07.574564 140544263226496 train.py:254] Step #12702: rate 0.000100, accuracy 88.0%, cross entropy 0.355039
# DEBUG:tensorflow:Step #12703: rate 0.000100, accuracy 89.0%, cross entropy 0.279011
# I0405 16:49:07.953244 140544263226496 train.py:254] Step #12703: rate 0.000100, accuracy 89.0%, cross entropy 0.279011
# DEBUG:tensorflow:Step #12704: rate 0.000100, accuracy 93.0%, cross entropy 0.224004
# I0405 16:49:08.311456 140544263226496 train.py:254] Step #12704: rate 0.000100, accuracy 93.0%, cross entropy 0.224004
# DEBUG:tensorflow:Step #12705: rate 0.000100, accuracy 88.0%, cross entropy 0.272965
# I0405 16:49:08.665439 140544263226496 train.py:254] Step #12705: rate 0.000100, accuracy 88.0%, cross entropy 0.272965
# DEBUG:tensorflow:Step #12706: rate 0.000100, accuracy 89.0%, cross entropy 0.272347
# I0405 16:49:09.044391 140544263226496 train.py:254] Step #12706: rate 0.000100, accuracy 89.0%, cross entropy 0.272347
# DEBUG:tensorflow:Step #12707: rate 0.000100, accuracy 88.0%, cross entropy 0.306420
# I0405 16:49:09.403254 140544263226496 train.py:254] Step #12707: rate 0.000100, accuracy 88.0%, cross entropy 0.306420
# DEBUG:tensorflow:Step #12708: rate 0.000100, accuracy 90.0%, cross entropy 0.289253
# I0405 16:49:09.808516 140544263226496 train.py:254] Step #12708: rate 0.000100, accuracy 90.0%, cross entropy 0.289253
# DEBUG:tensorflow:Step #12709: rate 0.000100, accuracy 91.0%, cross entropy 0.230980
# I0405 16:49:10.186264 140544263226496 train.py:254] Step #12709: rate 0.000100, accuracy 91.0%, cross entropy 0.230980
# DEBUG:tensorflow:Step #12710: rate 0.000100, accuracy 82.0%, cross entropy 0.435092
# I0405 16:49:10.542036 140544263226496 train.py:254] Step #12710: rate 0.000100, accuracy 82.0%, cross entropy 0.435092
# DEBUG:tensorflow:Step #12711: rate 0.000100, accuracy 95.0%, cross entropy 0.193740
# I0405 16:49:10.899943 140544263226496 train.py:254] Step #12711: rate 0.000100, accuracy 95.0%, cross entropy 0.193740
# DEBUG:tensorflow:Step #12712: rate 0.000100, accuracy 86.0%, cross entropy 0.368776
# I0405 16:49:11.269896 140544263226496 train.py:254] Step #12712: rate 0.000100, accuracy 86.0%, cross entropy 0.368776
# DEBUG:tensorflow:Step #12713: rate 0.000100, accuracy 88.0%, cross entropy 0.328680
# I0405 16:49:11.627538 140544263226496 train.py:254] Step #12713: rate 0.000100, accuracy 88.0%, cross entropy 0.328680
# DEBUG:tensorflow:Step #12714: rate 0.000100, accuracy 88.0%, cross entropy 0.365551
# I0405 16:49:11.999371 140544263226496 train.py:254] Step #12714: rate 0.000100, accuracy 88.0%, cross entropy 0.365551
# DEBUG:tensorflow:Step #12715: rate 0.000100, accuracy 94.0%, cross entropy 0.221470
# I0405 16:49:12.352171 140544263226496 train.py:254] Step #12715: rate 0.000100, accuracy 94.0%, cross entropy 0.221470
# DEBUG:tensorflow:Step #12716: rate 0.000100, accuracy 92.0%, cross entropy 0.271340
# I0405 16:49:12.706405 140544263226496 train.py:254] Step #12716: rate 0.000100, accuracy 92.0%, cross entropy 0.271340
# DEBUG:tensorflow:Step #12717: rate 0.000100, accuracy 88.0%, cross entropy 0.297188
# I0405 16:49:13.074278 140544263226496 train.py:254] Step #12717: rate 0.000100, accuracy 88.0%, cross entropy 0.297188
# DEBUG:tensorflow:Step #12718: rate 0.000100, accuracy 89.0%, cross entropy 0.355346
# I0405 16:49:13.443571 140544263226496 train.py:254] Step #12718: rate 0.000100, accuracy 89.0%, cross entropy 0.355346
# DEBUG:tensorflow:Step #12719: rate 0.000100, accuracy 94.0%, cross entropy 0.198268
# I0405 16:49:13.804860 140544263226496 train.py:254] Step #12719: rate 0.000100, accuracy 94.0%, cross entropy 0.198268
# DEBUG:tensorflow:Step #12720: rate 0.000100, accuracy 91.0%, cross entropy 0.268344
# I0405 16:49:14.294475 140544263226496 train.py:254] Step #12720: rate 0.000100, accuracy 91.0%, cross entropy 0.268344
# DEBUG:tensorflow:Step #12721: rate 0.000100, accuracy 92.0%, cross entropy 0.190566
# I0405 16:49:14.831784 140544263226496 train.py:254] Step #12721: rate 0.000100, accuracy 92.0%, cross entropy 0.190566
# DEBUG:tensorflow:Step #12722: rate 0.000100, accuracy 90.0%, cross entropy 0.317074
# I0405 16:49:15.369319 140544263226496 train.py:254] Step #12722: rate 0.000100, accuracy 90.0%, cross entropy 0.317074
# DEBUG:tensorflow:Step #12723: rate 0.000100, accuracy 88.0%, cross entropy 0.309240
# I0405 16:49:15.901568 140544263226496 train.py:254] Step #12723: rate 0.000100, accuracy 88.0%, cross entropy 0.309240
# DEBUG:tensorflow:Step #12724: rate 0.000100, accuracy 87.0%, cross entropy 0.309312
# I0405 16:49:16.454366 140544263226496 train.py:254] Step #12724: rate 0.000100, accuracy 87.0%, cross entropy 0.309312
# DEBUG:tensorflow:Step #12725: rate 0.000100, accuracy 88.0%, cross entropy 0.344339
# I0405 16:49:16.994353 140544263226496 train.py:254] Step #12725: rate 0.000100, accuracy 88.0%, cross entropy 0.344339
# DEBUG:tensorflow:Step #12726: rate 0.000100, accuracy 96.0%, cross entropy 0.187648
# I0405 16:49:17.451795 140544263226496 train.py:254] Step #12726: rate 0.000100, accuracy 96.0%, cross entropy 0.187648
# DEBUG:tensorflow:Step #12727: rate 0.000100, accuracy 90.0%, cross entropy 0.331713
# I0405 16:49:17.811256 140544263226496 train.py:254] Step #12727: rate 0.000100, accuracy 90.0%, cross entropy 0.331713
# DEBUG:tensorflow:Step #12728: rate 0.000100, accuracy 85.0%, cross entropy 0.371605
# I0405 16:49:18.180521 140544263226496 train.py:254] Step #12728: rate 0.000100, accuracy 85.0%, cross entropy 0.371605
# DEBUG:tensorflow:Step #12729: rate 0.000100, accuracy 90.0%, cross entropy 0.253732
# I0405 16:49:18.549638 140544263226496 train.py:254] Step #12729: rate 0.000100, accuracy 90.0%, cross entropy 0.253732
# DEBUG:tensorflow:Step #12730: rate 0.000100, accuracy 89.0%, cross entropy 0.324546
# I0405 16:49:18.914062 140544263226496 train.py:254] Step #12730: rate 0.000100, accuracy 89.0%, cross entropy 0.324546
# DEBUG:tensorflow:Step #12731: rate 0.000100, accuracy 87.0%, cross entropy 0.347553
# I0405 16:49:19.285217 140544263226496 train.py:254] Step #12731: rate 0.000100, accuracy 87.0%, cross entropy 0.347553
# DEBUG:tensorflow:Step #12732: rate 0.000100, accuracy 93.0%, cross entropy 0.159560
# I0405 16:49:19.661135 140544263226496 train.py:254] Step #12732: rate 0.000100, accuracy 93.0%, cross entropy 0.159560
# DEBUG:tensorflow:Step #12733: rate 0.000100, accuracy 90.0%, cross entropy 0.347745
# I0405 16:49:20.030748 140544263226496 train.py:254] Step #12733: rate 0.000100, accuracy 90.0%, cross entropy 0.347745
# DEBUG:tensorflow:Step #12734: rate 0.000100, accuracy 89.0%, cross entropy 0.372069
# I0405 16:49:20.394055 140544263226496 train.py:254] Step #12734: rate 0.000100, accuracy 89.0%, cross entropy 0.372069
# DEBUG:tensorflow:Step #12735: rate 0.000100, accuracy 84.0%, cross entropy 0.348622
# I0405 16:49:20.780432 140544263226496 train.py:254] Step #12735: rate 0.000100, accuracy 84.0%, cross entropy 0.348622
# DEBUG:tensorflow:Step #12736: rate 0.000100, accuracy 89.0%, cross entropy 0.247345
# I0405 16:49:21.157256 140544263226496 train.py:254] Step #12736: rate 0.000100, accuracy 89.0%, cross entropy 0.247345
# DEBUG:tensorflow:Step #12737: rate 0.000100, accuracy 90.0%, cross entropy 0.283898
# I0405 16:49:21.528315 140544263226496 train.py:254] Step #12737: rate 0.000100, accuracy 90.0%, cross entropy 0.283898
# DEBUG:tensorflow:Step #12738: rate 0.000100, accuracy 86.0%, cross entropy 0.332700
# I0405 16:49:21.906476 140544263226496 train.py:254] Step #12738: rate 0.000100, accuracy 86.0%, cross entropy 0.332700
# DEBUG:tensorflow:Step #12739: rate 0.000100, accuracy 94.0%, cross entropy 0.201425
# I0405 16:49:22.281738 140544263226496 train.py:254] Step #12739: rate 0.000100, accuracy 94.0%, cross entropy 0.201425
# DEBUG:tensorflow:Step #12740: rate 0.000100, accuracy 93.0%, cross entropy 0.264234
# I0405 16:49:22.669615 140544263226496 train.py:254] Step #12740: rate 0.000100, accuracy 93.0%, cross entropy 0.264234
# DEBUG:tensorflow:Step #12741: rate 0.000100, accuracy 93.0%, cross entropy 0.188671
# I0405 16:49:23.032130 140544263226496 train.py:254] Step #12741: rate 0.000100, accuracy 93.0%, cross entropy 0.188671
# DEBUG:tensorflow:Step #12742: rate 0.000100, accuracy 89.0%, cross entropy 0.258009
# I0405 16:49:23.393393 140544263226496 train.py:254] Step #12742: rate 0.000100, accuracy 89.0%, cross entropy 0.258009
# DEBUG:tensorflow:Step #12743: rate 0.000100, accuracy 83.0%, cross entropy 0.388991
# I0405 16:49:23.775490 140544263226496 train.py:254] Step #12743: rate 0.000100, accuracy 83.0%, cross entropy 0.388991
# DEBUG:tensorflow:Step #12744: rate 0.000100, accuracy 90.0%, cross entropy 0.302377
# I0405 16:49:24.139546 140544263226496 train.py:254] Step #12744: rate 0.000100, accuracy 90.0%, cross entropy 0.302377
# DEBUG:tensorflow:Step #12745: rate 0.000100, accuracy 85.0%, cross entropy 0.342264
# I0405 16:49:24.497265 140544263226496 train.py:254] Step #12745: rate 0.000100, accuracy 85.0%, cross entropy 0.342264
# DEBUG:tensorflow:Step #12746: rate 0.000100, accuracy 93.0%, cross entropy 0.296442
# I0405 16:49:24.876643 140544263226496 train.py:254] Step #12746: rate 0.000100, accuracy 93.0%, cross entropy 0.296442
# DEBUG:tensorflow:Step #12747: rate 0.000100, accuracy 85.0%, cross entropy 0.295583
# I0405 16:49:25.245665 140544263226496 train.py:254] Step #12747: rate 0.000100, accuracy 85.0%, cross entropy 0.295583
# DEBUG:tensorflow:Step #12748: rate 0.000100, accuracy 87.0%, cross entropy 0.289490
# I0405 16:49:25.618082 140544263226496 train.py:254] Step #12748: rate 0.000100, accuracy 87.0%, cross entropy 0.289490
# DEBUG:tensorflow:Step #12749: rate 0.000100, accuracy 91.0%, cross entropy 0.218282
# I0405 16:49:25.994776 140544263226496 train.py:254] Step #12749: rate 0.000100, accuracy 91.0%, cross entropy 0.218282
# DEBUG:tensorflow:Step #12750: rate 0.000100, accuracy 88.0%, cross entropy 0.304309
# I0405 16:49:26.358240 140544263226496 train.py:254] Step #12750: rate 0.000100, accuracy 88.0%, cross entropy 0.304309
# DEBUG:tensorflow:Step #12751: rate 0.000100, accuracy 92.0%, cross entropy 0.207033
# I0405 16:49:26.731134 140544263226496 train.py:254] Step #12751: rate 0.000100, accuracy 92.0%, cross entropy 0.207033
# DEBUG:tensorflow:Step #12752: rate 0.000100, accuracy 85.0%, cross entropy 0.418505
# I0405 16:49:27.101151 140544263226496 train.py:254] Step #12752: rate 0.000100, accuracy 85.0%, cross entropy 0.418505
# DEBUG:tensorflow:Step #12753: rate 0.000100, accuracy 90.0%, cross entropy 0.282318
# I0405 16:49:27.630691 140544263226496 train.py:254] Step #12753: rate 0.000100, accuracy 90.0%, cross entropy 0.282318
# DEBUG:tensorflow:Step #12754: rate 0.000100, accuracy 91.0%, cross entropy 0.208652
# I0405 16:49:28.194625 140544263226496 train.py:254] Step #12754: rate 0.000100, accuracy 91.0%, cross entropy 0.208652
# DEBUG:tensorflow:Step #12755: rate 0.000100, accuracy 88.0%, cross entropy 0.336377
# I0405 16:49:28.737673 140544263226496 train.py:254] Step #12755: rate 0.000100, accuracy 88.0%, cross entropy 0.336377
# DEBUG:tensorflow:Step #12756: rate 0.000100, accuracy 91.0%, cross entropy 0.262457
# I0405 16:49:29.306609 140544263226496 train.py:254] Step #12756: rate 0.000100, accuracy 91.0%, cross entropy 0.262457
# DEBUG:tensorflow:Step #12757: rate 0.000100, accuracy 95.0%, cross entropy 0.221271
# I0405 16:49:29.844993 140544263226496 train.py:254] Step #12757: rate 0.000100, accuracy 95.0%, cross entropy 0.221271
# DEBUG:tensorflow:Step #12758: rate 0.000100, accuracy 84.0%, cross entropy 0.393399
# I0405 16:49:30.438209 140544263226496 train.py:254] Step #12758: rate 0.000100, accuracy 84.0%, cross entropy 0.393399
# DEBUG:tensorflow:Step #12759: rate 0.000100, accuracy 94.0%, cross entropy 0.206556
# I0405 16:49:30.806489 140544263226496 train.py:254] Step #12759: rate 0.000100, accuracy 94.0%, cross entropy 0.206556
# DEBUG:tensorflow:Step #12760: rate 0.000100, accuracy 91.0%, cross entropy 0.235694
# I0405 16:49:31.175462 140544263226496 train.py:254] Step #12760: rate 0.000100, accuracy 91.0%, cross entropy 0.235694
# DEBUG:tensorflow:Step #12761: rate 0.000100, accuracy 94.0%, cross entropy 0.221948
# I0405 16:49:31.540446 140544263226496 train.py:254] Step #12761: rate 0.000100, accuracy 94.0%, cross entropy 0.221948
# DEBUG:tensorflow:Step #12762: rate 0.000100, accuracy 92.0%, cross entropy 0.310478
# I0405 16:49:31.894901 140544263226496 train.py:254] Step #12762: rate 0.000100, accuracy 92.0%, cross entropy 0.310478
# DEBUG:tensorflow:Step #12763: rate 0.000100, accuracy 87.0%, cross entropy 0.354714
# I0405 16:49:32.259528 140544263226496 train.py:254] Step #12763: rate 0.000100, accuracy 87.0%, cross entropy 0.354714
# DEBUG:tensorflow:Step #12764: rate 0.000100, accuracy 87.0%, cross entropy 0.286241
# I0405 16:49:32.621539 140544263226496 train.py:254] Step #12764: rate 0.000100, accuracy 87.0%, cross entropy 0.286241
# DEBUG:tensorflow:Step #12765: rate 0.000100, accuracy 87.0%, cross entropy 0.338172
# I0405 16:49:32.969518 140544263226496 train.py:254] Step #12765: rate 0.000100, accuracy 87.0%, cross entropy 0.338172
# DEBUG:tensorflow:Step #12766: rate 0.000100, accuracy 91.0%, cross entropy 0.237773
# I0405 16:49:33.341660 140544263226496 train.py:254] Step #12766: rate 0.000100, accuracy 91.0%, cross entropy 0.237773
# DEBUG:tensorflow:Step #12767: rate 0.000100, accuracy 87.0%, cross entropy 0.374899
# I0405 16:49:33.689261 140544263226496 train.py:254] Step #12767: rate 0.000100, accuracy 87.0%, cross entropy 0.374899
# ...
# DEBUG:tensorflow:Step #14929: rate 0.000100, accuracy 96.0%, cross entropy 0.168958
# I0405 17:04:03.729494 140544263226496 train.py:254] Step #14929: rate 0.000100, accuracy 96.0%, cross entropy 0.168958
# DEBUG:tensorflow:Step #14930: rate 0.000100, accuracy 87.0%, cross entropy 0.382057
# I0405 17:04:04.119539 140544263226496 train.py:254] Step #14930: rate 0.000100, accuracy 87.0%, cross entropy 0.382057
# DEBUG:tensorflow:Step #14931: rate 0.000100, accuracy 82.0%, cross entropy 0.462634
# I0405 17:04:04.474321 140544263226496 train.py:254] Step #14931: rate 0.000100, accuracy 82.0%, cross entropy 0.462634
# DEBUG:tensorflow:Step #14932: rate 0.000100, accuracy 94.0%, cross entropy 0.169684
# I0405 17:04:04.907396 140544263226496 train.py:254] Step #14932: rate 0.000100, accuracy 94.0%, cross entropy 0.169684
# DEBUG:tensorflow:Step #14933: rate 0.000100, accuracy 86.0%, cross entropy 0.344795
# I0405 17:04:05.474406 140544263226496 train.py:254] Step #14933: rate 0.000100, accuracy 86.0%, cross entropy 0.344795
# DEBUG:tensorflow:Step #14934: rate 0.000100, accuracy 88.0%, cross entropy 0.293706
# I0405 17:04:06.019814 140544263226496 train.py:254] Step #14934: rate 0.000100, accuracy 88.0%, cross entropy 0.293706
# DEBUG:tensorflow:Step #14935: rate 0.000100, accuracy 88.0%, cross entropy 0.330596
# I0405 17:04:06.562728 140544263226496 train.py:254] Step #14935: rate 0.000100, accuracy 88.0%, cross entropy 0.330596
# DEBUG:tensorflow:Step #14936: rate 0.000100, accuracy 83.0%, cross entropy 0.453911
# I0405 17:04:07.099401 140544263226496 train.py:254] Step #14936: rate 0.000100, accuracy 83.0%, cross entropy 0.453911
# DEBUG:tensorflow:Step #14937: rate 0.000100, accuracy 94.0%, cross entropy 0.239604
# I0405 17:04:07.634762 140544263226496 train.py:254] Step #14937: rate 0.000100, accuracy 94.0%, cross entropy 0.239604
# DEBUG:tensorflow:Step #14938: rate 0.000100, accuracy 91.0%, cross entropy 0.182493
# I0405 17:04:08.139424 140544263226496 train.py:254] Step #14938: rate 0.000100, accuracy 91.0%, cross entropy 0.182493
# DEBUG:tensorflow:Step #14939: rate 0.000100, accuracy 93.0%, cross entropy 0.260908
# I0405 17:04:08.511322 140544263226496 train.py:254] Step #14939: rate 0.000100, accuracy 93.0%, cross entropy 0.260908
# DEBUG:tensorflow:Step #14940: rate 0.000100, accuracy 88.0%, cross entropy 0.413786
# I0405 17:04:08.858963 140544263226496 train.py:254] Step #14940: rate 0.000100, accuracy 88.0%, cross entropy 0.413786
# DEBUG:tensorflow:Step #14941: rate 0.000100, accuracy 90.0%, cross entropy 0.285644
# I0405 17:04:09.210249 140544263226496 train.py:254] Step #14941: rate 0.000100, accuracy 90.0%, cross entropy 0.285644
# DEBUG:tensorflow:Step #14942: rate 0.000100, accuracy 93.0%, cross entropy 0.228544
# I0405 17:04:09.579583 140544263226496 train.py:254] Step #14942: rate 0.000100, accuracy 93.0%, cross entropy 0.228544
# DEBUG:tensorflow:Step #14943: rate 0.000100, accuracy 90.0%, cross entropy 0.285774
# I0405 17:04:09.928499 140544263226496 train.py:254] Step #14943: rate 0.000100, accuracy 90.0%, cross entropy 0.285774
# DEBUG:tensorflow:Step #14944: rate 0.000100, accuracy 90.0%, cross entropy 0.297915
# I0405 17:04:10.273712 140544263226496 train.py:254] Step #14944: rate 0.000100, accuracy 90.0%, cross entropy 0.297915
# DEBUG:tensorflow:Step #14945: rate 0.000100, accuracy 82.0%, cross entropy 0.460907
# I0405 17:04:10.643153 140544263226496 train.py:254] Step #14945: rate 0.000100, accuracy 82.0%, cross entropy 0.460907
# DEBUG:tensorflow:Step #14946: rate 0.000100, accuracy 94.0%, cross entropy 0.265790
# I0405 17:04:10.989855 140544263226496 train.py:254] Step #14946: rate 0.000100, accuracy 94.0%, cross entropy 0.265790
# DEBUG:tensorflow:Step #14947: rate 0.000100, accuracy 87.0%, cross entropy 0.384233
# I0405 17:04:11.338246 140544263226496 train.py:254] Step #14947: rate 0.000100, accuracy 87.0%, cross entropy 0.384233
# DEBUG:tensorflow:Step #14948: rate 0.000100, accuracy 89.0%, cross entropy 0.273247
# I0405 17:04:11.698679 140544263226496 train.py:254] Step #14948: rate 0.000100, accuracy 89.0%, cross entropy 0.273247
# DEBUG:tensorflow:Step #14949: rate 0.000100, accuracy 88.0%, cross entropy 0.340289
# I0405 17:04:12.055381 140544263226496 train.py:254] Step #14949: rate 0.000100, accuracy 88.0%, cross entropy 0.340289
# DEBUG:tensorflow:Step #14950: rate 0.000100, accuracy 90.0%, cross entropy 0.274046
# I0405 17:04:12.405349 140544263226496 train.py:254] Step #14950: rate 0.000100, accuracy 90.0%, cross entropy 0.274046
# DEBUG:tensorflow:Step #14951: rate 0.000100, accuracy 85.0%, cross entropy 0.405953
# I0405 17:04:12.768870 140544263226496 train.py:254] Step #14951: rate 0.000100, accuracy 85.0%, cross entropy 0.405953
# DEBUG:tensorflow:Step #14952: rate 0.000100, accuracy 90.0%, cross entropy 0.220425
# I0405 17:04:13.130443 140544263226496 train.py:254] Step #14952: rate 0.000100, accuracy 90.0%, cross entropy 0.220425
# DEBUG:tensorflow:Step #14953: rate 0.000100, accuracy 85.0%, cross entropy 0.345259
# I0405 17:04:13.495395 140544263226496 train.py:254] Step #14953: rate 0.000100, accuracy 85.0%, cross entropy 0.345259
# DEBUG:tensorflow:Step #14954: rate 0.000100, accuracy 89.0%, cross entropy 0.341654
# I0405 17:04:13.854478 140544263226496 train.py:254] Step #14954: rate 0.000100, accuracy 89.0%, cross entropy 0.341654
# DEBUG:tensorflow:Step #14955: rate 0.000100, accuracy 81.0%, cross entropy 0.484196
# I0405 17:04:14.210093 140544263226496 train.py:254] Step #14955: rate 0.000100, accuracy 81.0%, cross entropy 0.484196
# DEBUG:tensorflow:Step #14956: rate 0.000100, accuracy 85.0%, cross entropy 0.434439
# I0405 17:04:14.558009 140544263226496 train.py:254] Step #14956: rate 0.000100, accuracy 85.0%, cross entropy 0.434439
# DEBUG:tensorflow:Step #14957: rate 0.000100, accuracy 86.0%, cross entropy 0.332264
# I0405 17:04:14.921792 140544263226496 train.py:254] Step #14957: rate 0.000100, accuracy 86.0%, cross entropy 0.332264
# DEBUG:tensorflow:Step #14958: rate 0.000100, accuracy 89.0%, cross entropy 0.307166
# I0405 17:04:15.286076 140544263226496 train.py:254] Step #14958: rate 0.000100, accuracy 89.0%, cross entropy 0.307166
# DEBUG:tensorflow:Step #14959: rate 0.000100, accuracy 90.0%, cross entropy 0.279002
# I0405 17:04:15.645771 140544263226496 train.py:254] Step #14959: rate 0.000100, accuracy 90.0%, cross entropy 0.279002
# DEBUG:tensorflow:Step #14960: rate 0.000100, accuracy 93.0%, cross entropy 0.197127
# I0405 17:04:16.017034 140544263226496 train.py:254] Step #14960: rate 0.000100, accuracy 93.0%, cross entropy 0.197127
# DEBUG:tensorflow:Step #14961: rate 0.000100, accuracy 92.0%, cross entropy 0.261086
# I0405 17:04:16.368430 140544263226496 train.py:254] Step #14961: rate 0.000100, accuracy 92.0%, cross entropy 0.261086
# DEBUG:tensorflow:Step #14962: rate 0.000100, accuracy 88.0%, cross entropy 0.402090
# I0405 17:04:16.782608 140544263226496 train.py:254] Step #14962: rate 0.000100, accuracy 88.0%, cross entropy 0.402090
# DEBUG:tensorflow:Step #14963: rate 0.000100, accuracy 92.0%, cross entropy 0.209815
# I0405 17:04:17.141554 140544263226496 train.py:254] Step #14963: rate 0.000100, accuracy 92.0%, cross entropy 0.209815
# DEBUG:tensorflow:Step #14964: rate 0.000100, accuracy 87.0%, cross entropy 0.334098
# I0405 17:04:17.500097 140544263226496 train.py:254] Step #14964: rate 0.000100, accuracy 87.0%, cross entropy 0.334098
# DEBUG:tensorflow:Step #14965: rate 0.000100, accuracy 90.0%, cross entropy 0.304639
# I0405 17:04:17.883036 140544263226496 train.py:254] Step #14965: rate 0.000100, accuracy 90.0%, cross entropy 0.304639
# DEBUG:tensorflow:Step #14966: rate 0.000100, accuracy 88.0%, cross entropy 0.315617
# I0405 17:04:18.357277 140544263226496 train.py:254] Step #14966: rate 0.000100, accuracy 88.0%, cross entropy 0.315617
# DEBUG:tensorflow:Step #14967: rate 0.000100, accuracy 85.0%, cross entropy 0.380077
# I0405 17:04:18.922847 140544263226496 train.py:254] Step #14967: rate 0.000100, accuracy 85.0%, cross entropy 0.380077
# DEBUG:tensorflow:Step #14968: rate 0.000100, accuracy 93.0%, cross entropy 0.238674
# I0405 17:04:19.474340 140544263226496 train.py:254] Step #14968: rate 0.000100, accuracy 93.0%, cross entropy 0.238674
# DEBUG:tensorflow:Step #14969: rate 0.000100, accuracy 89.0%, cross entropy 0.298669
# I0405 17:04:20.046939 140544263226496 train.py:254] Step #14969: rate 0.000100, accuracy 89.0%, cross entropy 0.298669
# DEBUG:tensorflow:Step #14970: rate 0.000100, accuracy 95.0%, cross entropy 0.195821
# I0405 17:04:20.596784 140544263226496 train.py:254] Step #14970: rate 0.000100, accuracy 95.0%, cross entropy 0.195821
# DEBUG:tensorflow:Step #14971: rate 0.000100, accuracy 90.0%, cross entropy 0.264728
# I0405 17:04:21.166579 140544263226496 train.py:254] Step #14971: rate 0.000100, accuracy 90.0%, cross entropy 0.264728
# DEBUG:tensorflow:Step #14972: rate 0.000100, accuracy 89.0%, cross entropy 0.285697
# I0405 17:04:21.585015 140544263226496 train.py:254] Step #14972: rate 0.000100, accuracy 89.0%, cross entropy 0.285697
# DEBUG:tensorflow:Step #14973: rate 0.000100, accuracy 93.0%, cross entropy 0.200741
# I0405 17:04:21.960435 140544263226496 train.py:254] Step #14973: rate 0.000100, accuracy 93.0%, cross entropy 0.200741
# DEBUG:tensorflow:Step #14974: rate 0.000100, accuracy 85.0%, cross entropy 0.330566
# I0405 17:04:22.332465 140544263226496 train.py:254] Step #14974: rate 0.000100, accuracy 85.0%, cross entropy 0.330566
# DEBUG:tensorflow:Step #14975: rate 0.000100, accuracy 88.0%, cross entropy 0.261162
# I0405 17:04:22.689089 140544263226496 train.py:254] Step #14975: rate 0.000100, accuracy 88.0%, cross entropy 0.261162
# DEBUG:tensorflow:Step #14976: rate 0.000100, accuracy 91.0%, cross entropy 0.266800
# I0405 17:04:23.057784 140544263226496 train.py:254] Step #14976: rate 0.000100, accuracy 91.0%, cross entropy 0.266800
# DEBUG:tensorflow:Step #14977: rate 0.000100, accuracy 90.0%, cross entropy 0.252211
# I0405 17:04:23.433310 140544263226496 train.py:254] Step #14977: rate 0.000100, accuracy 90.0%, cross entropy 0.252211
# DEBUG:tensorflow:Step #14978: rate 0.000100, accuracy 88.0%, cross entropy 0.282355
# I0405 17:04:23.810642 140544263226496 train.py:254] Step #14978: rate 0.000100, accuracy 88.0%, cross entropy 0.282355
# DEBUG:tensorflow:Step #14979: rate 0.000100, accuracy 87.0%, cross entropy 0.322795
# I0405 17:04:24.202376 140544263226496 train.py:254] Step #14979: rate 0.000100, accuracy 87.0%, cross entropy 0.322795
# DEBUG:tensorflow:Step #14980: rate 0.000100, accuracy 90.0%, cross entropy 0.245351
# I0405 17:04:24.563952 140544263226496 train.py:254] Step #14980: rate 0.000100, accuracy 90.0%, cross entropy 0.245351
# DEBUG:tensorflow:Step #14981: rate 0.000100, accuracy 86.0%, cross entropy 0.336451
# I0405 17:04:24.924736 140544263226496 train.py:254] Step #14981: rate 0.000100, accuracy 86.0%, cross entropy 0.336451
# DEBUG:tensorflow:Step #14982: rate 0.000100, accuracy 87.0%, cross entropy 0.324763
# I0405 17:04:25.303885 140544263226496 train.py:254] Step #14982: rate 0.000100, accuracy 87.0%, cross entropy 0.324763
# DEBUG:tensorflow:Step #14983: rate 0.000100, accuracy 86.0%, cross entropy 0.409951
# I0405 17:04:25.682672 140544263226496 train.py:254] Step #14983: rate 0.000100, accuracy 86.0%, cross entropy 0.409951
# DEBUG:tensorflow:Step #14984: rate 0.000100, accuracy 93.0%, cross entropy 0.245748
# I0405 17:04:26.053550 140544263226496 train.py:254] Step #14984: rate 0.000100, accuracy 93.0%, cross entropy 0.245748
# DEBUG:tensorflow:Step #14985: rate 0.000100, accuracy 86.0%, cross entropy 0.426288
# I0405 17:04:26.439399 140544263226496 train.py:254] Step #14985: rate 0.000100, accuracy 86.0%, cross entropy 0.426288
# DEBUG:tensorflow:Step #14986: rate 0.000100, accuracy 87.0%, cross entropy 0.373478
# I0405 17:04:26.798418 140544263226496 train.py:254] Step #14986: rate 0.000100, accuracy 87.0%, cross entropy 0.373478
# DEBUG:tensorflow:Step #14987: rate 0.000100, accuracy 90.0%, cross entropy 0.380271
# I0405 17:04:27.167990 140544263226496 train.py:254] Step #14987: rate 0.000100, accuracy 90.0%, cross entropy 0.380271
# DEBUG:tensorflow:Step #14988: rate 0.000100, accuracy 92.0%, cross entropy 0.237943
# I0405 17:04:27.546134 140544263226496 train.py:254] Step #14988: rate 0.000100, accuracy 92.0%, cross entropy 0.237943
# DEBUG:tensorflow:Step #14989: rate 0.000100, accuracy 88.0%, cross entropy 0.367929
# I0405 17:04:27.911620 140544263226496 train.py:254] Step #14989: rate 0.000100, accuracy 88.0%, cross entropy 0.367929
# DEBUG:tensorflow:Step #14990: rate 0.000100, accuracy 83.0%, cross entropy 0.458901
# I0405 17:04:28.330916 140544263226496 train.py:254] Step #14990: rate 0.000100, accuracy 83.0%, cross entropy 0.458901
# DEBUG:tensorflow:Step #14991: rate 0.000100, accuracy 90.0%, cross entropy 0.254878
# I0405 17:04:28.695620 140544263226496 train.py:254] Step #14991: rate 0.000100, accuracy 90.0%, cross entropy 0.254878
# DEBUG:tensorflow:Step #14992: rate 0.000100, accuracy 88.0%, cross entropy 0.457184
# I0405 17:04:29.058385 140544263226496 train.py:254] Step #14992: rate 0.000100, accuracy 88.0%, cross entropy 0.457184
# DEBUG:tensorflow:Step #14993: rate 0.000100, accuracy 86.0%, cross entropy 0.276282
# I0405 17:04:29.430728 140544263226496 train.py:254] Step #14993: rate 0.000100, accuracy 86.0%, cross entropy 0.276282
# DEBUG:tensorflow:Step #14994: rate 0.000100, accuracy 87.0%, cross entropy 0.317614
# I0405 17:04:29.792165 140544263226496 train.py:254] Step #14994: rate 0.000100, accuracy 87.0%, cross entropy 0.317614
# DEBUG:tensorflow:Step #14995: rate 0.000100, accuracy 94.0%, cross entropy 0.214687
# I0405 17:04:30.164923 140544263226496 train.py:254] Step #14995: rate 0.000100, accuracy 94.0%, cross entropy 0.214687
# DEBUG:tensorflow:Step #14996: rate 0.000100, accuracy 94.0%, cross entropy 0.226582
# I0405 17:04:30.541259 140544263226496 train.py:254] Step #14996: rate 0.000100, accuracy 94.0%, cross entropy 0.226582
# DEBUG:tensorflow:Step #14997: rate 0.000100, accuracy 95.0%, cross entropy 0.211591
# I0405 17:04:30.904526 140544263226496 train.py:254] Step #14997: rate 0.000100, accuracy 95.0%, cross entropy 0.211591
# DEBUG:tensorflow:Step #14998: rate 0.000100, accuracy 94.0%, cross entropy 0.164799
# I0405 17:04:31.266787 140544263226496 train.py:254] Step #14998: rate 0.000100, accuracy 94.0%, cross entropy 0.164799
# DEBUG:tensorflow:Step #14999: rate 0.000100, accuracy 93.0%, cross entropy 0.219260
# I0405 17:04:31.814905 140544263226496 train.py:254] Step #14999: rate 0.000100, accuracy 93.0%, cross entropy 0.219260
# DEBUG:tensorflow:Step #15000: rate 0.000100, accuracy 84.0%, cross entropy 0.349334
# I0405 17:04:32.378836 140544263226496 train.py:254] Step #15000: rate 0.000100, accuracy 84.0%, cross entropy 0.349334
# INFO:tensorflow:Step #15000: rate 0.000100, accuracy 84.0%, cross entropy 0.349334
# I0405 17:04:32.379035 140544263226496 train.py:260] Step #15000: rate 0.000100, accuracy 84.0%, cross entropy 0.349334
# INFO:tensorflow:Confusion Matrix:
#  [[201   0   0   0]
#  [  1 160   7  33]
#  [  1   7 383   6]
#  [  5  25   8 368]]
# I0405 17:04:37.361573 140544263226496 train.py:287] Confusion Matrix:
#  [[201   0   0   0]
#  [  1 160   7  33]
#  [  1   7 383   6]
#  [  5  25   8 368]]
# INFO:tensorflow:Step 15000: Validation accuracy = 92.3% (N=1205)
# I0405 17:04:37.361901 140544263226496 train.py:288] Step 15000: Validation accuracy = 92.3% (N=1205)
# INFO:tensorflow:Saving to "train/tiny_conv.ckpt-15000"
# I0405 17:04:37.362042 140544263226496 train.py:296] Saving to "train/tiny_conv.ckpt-15000"
# INFO:tensorflow:set_size=1236
# I0405 17:04:37.374625 140544263226496 train.py:301] set_size=1236
# WARNING:tensorflow:Confusion Matrix:
#  [[199   4   0   3]
#  [  1 166  11  28]
#  [  3  12 401   3]
#  [  2  22   5 376]]
# W0405 17:04:43.332646 140544263226496 train.py:320] Confusion Matrix:
#  [[199   4   0   3]
#  [  1 166  11  28]
#  [  3  12 401   3]
#  [  2  22   5 376]]
# WARNING:tensorflow:Final test accuracy = 92.4% (N=1236)
# W0405 17:04:43.332863 140544263226496 train.py:321] Final test accuracy = 92.4% (N=1236)

# %% [markdown]
# # Generating your Model
# Just like with the pre-trained model we will now take the final checkpoint and convert it into a quantized TensorFlow Lite model.

# %% [markdown]
# ### Generate a TensorFlow Model for Inference
#
# Combine relevant training results (graph, weights, etc) into a single file for inference. This process is known as freezing a model and the resulting model is known as a frozen model/graph, as it cannot be further re-trained after this process.

# %%
# These commands modify the legacy TensorFlow example code to make it compatible with TensorFlow 2.x by replacing deprecated imports and removing
# runtime placeholders with constants, ensuring the model can be frozen and converted to TFLite without requiring dynamic inputs.

# Patch freeze.py to use the TF 2.x-compatible version of convert_variables_to_constants from tf.compat.v1.
# !sed -i 's/from tensorflow\.python\.framework import graph_util/from tensorflow.compat.v1.graph_util import convert_variables_to_constants/' tensorflow/tensorflow/examples/speech_commands/freeze.py

# Update function call to match the new import (remove graph_util prefix).
# !sed -i 's/graph_util\.convert_variables_to_constants/convert_variables_to_constants/' tensorflow/tensorflow/examples/speech_commands/freeze.py

# Replace placeholder for background_volume with a constant to eliminate runtime input requirements.
# !sed -i "s/tf\.compat\.v1\.placeholder(tf\.float32, name='background_volume')/tf.constant(0.0, dtype=tf.float32, name='background_volume')/" tensorflow/tensorflow/examples/speech_commands/input_data.py

# Replace placeholder for time_shift_padding with a constant to avoid dynamic input during inference.
# !sed -i "s/tf\.compat\.v1\.placeholder(tf\.int32, shape=\[2,2\], name='time_shift_padding')/tf.constant([[0, 0], [0, 0]], dtype=tf.int32, name='time_shift_padding')/" tensorflow/tensorflow/examples/speech_commands/input_data.py

# Replace placeholder for foreground_volume with a constant to ensure static graph for TFLite conversion.
# !sed -i "s/tf\.compat\.v1\.placeholder(tf\.float32, name='foreground_volume')/tf.constant(1.0, dtype=tf.float32, name='foreground_volume')/" tensorflow/tensorflow/examples/speech_commands/input_data.py

# %%
# !rm -rf {SAVED_MODEL}
# !python tensorflow/tensorflow/examples/speech_commands/freeze.py \
--wanted_words=$WANTED_WORDS \
--window_stride_ms=$WINDOW_STRIDE \
--preprocess=$PREPROCESS \
--model_architecture=$MODEL_ARCHITECTURE \
--start_checkpoint=$TRAIN_DIR$MODEL_ARCHITECTURE'.ckpt-'{TOTAL_STEPS} \
--save_format=saved_model \
--output_file={SAVED_MODEL}
# Out:
# 2026-04-05 17:04:48.142115: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1775408688.163733   27878 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1775408688.172194   27878 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1775408688.190812   27878 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1775408688.190864   27878 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1775408688.190869   27878 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1775408688.190874   27878 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# I0000 00:00:1775408695.397116   27878 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13757 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# INFO:tensorflow:Restoring parameters from train/tiny_conv.ckpt-15000
# I0405 17:04:55.442991 138101864531072 saver.py:1417] Restoring parameters from train/tiny_conv.ckpt-15000
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1775408695.444837   27878 mlir_graph_optimization_pass.cc:425] MLIR V1 optimization pass is not enabled
# WARNING:tensorflow:From /content/tensorflow/tensorflow/examples/speech_commands/freeze.py:234: convert_variables_to_constants (from tensorflow.python.framework.convert_to_constants) is deprecated and will be removed in a future version.
# Instructions for updating:
# This API was designed for TensorFlow v1. See https://www.tensorflow.org/guide/migrate for instructions on how to migrate your code to TensorFlow v2.
# W0405 17:04:55.460561 138101864531072 deprecation.py:50] From /content/tensorflow/tensorflow/examples/speech_commands/freeze.py:234: convert_variables_to_constants (from tensorflow.python.framework.convert_to_constants) is deprecated and will be removed in a future version.
# Instructions for updating:
# This API was designed for TensorFlow v1. See https://www.tensorflow.org/guide/migrate for instructions on how to migrate your code to TensorFlow v2.
# WARNING:tensorflow:From /usr/local/lib/python3.12/dist-packages/tensorflow/python/framework/convert_to_constants.py:946: extract_sub_graph (from tensorflow.python.framework.graph_util_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# This API was designed for TensorFlow v1. See https://www.tensorflow.org/guide/migrate for instructions on how to migrate your code to TensorFlow v2.
# W0405 17:04:55.460831 138101864531072 deprecation.py:50] From /usr/local/lib/python3.12/dist-packages/tensorflow/python/framework/convert_to_constants.py:946: extract_sub_graph (from tensorflow.python.framework.graph_util_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# This API was designed for TensorFlow v1. See https://www.tensorflow.org/guide/migrate for instructions on how to migrate your code to TensorFlow v2.
# WARNING:tensorflow:From /content/tensorflow/tensorflow/examples/speech_commands/freeze.py:188: build_tensor_info (from tensorflow.python.saved_model.utils_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# This API was designed for TensorFlow v1. See https://www.tensorflow.org/guide/migrate for instructions on how to migrate your code to TensorFlow v2.
# W0405 17:04:55.465524 138101864531072 deprecation.py:50] From /content/tensorflow/tensorflow/examples/speech_commands/freeze.py:188: build_tensor_info (from tensorflow.python.saved_model.utils_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# This API was designed for TensorFlow v1. See https://www.tensorflow.org/guide/migrate for instructions on how to migrate your code to TensorFlow v2.
# INFO:tensorflow:No assets to save.
# I0405 17:04:55.465960 138101864531072 builder_impl.py:686] No assets to save.
# INFO:tensorflow:No assets to write.
# I0405 17:04:55.466109 138101864531072 builder_impl.py:504] No assets to write.
# I0000 00:00:1775408695.477563   27878 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13757 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# INFO:tensorflow:SavedModel written to: models/saved_model/saved_model.pb
# I0405 17:04:55.503747 138101864531072 builder_impl.py:468] SavedModel written to: models/saved_model/saved_model.pb

# %%
float_converter = tf.lite.TFLiteConverter.from_saved_model(SAVED_MODEL)
float_tflite_model = float_converter.convert()

with open(FLOAT_MODEL_TFLITE, "wb") as f:
    f.write(float_tflite_model)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.12/dist-packages/tensorflow/lite/python/convert_saved_model.py:42: load (from tensorflow.python.saved_model.loader_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.saved_model.load` instead.
# WARNING:tensorflow:From /usr/local/lib/python3.12/dist-packages/tensorflow/lite/python/util.py:307: convert_variables_to_constants (from tensorflow.python.framework.convert_to_constants) is deprecated and will be removed in a future version.
# Instructions for updating:
# This API was designed for TensorFlow v1. See https://www.tensorflow.org/guide/migrate for instructions on how to migrate your code to TensorFlow v2.
# WARNING:tensorflow:From /usr/local/lib/python3.12/dist-packages/tensorflow/python/framework/convert_to_constants.py:946: extract_sub_graph (from tensorflow.python.framework.graph_util_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# This API was designed for TensorFlow v1. See https://www.tensorflow.org/guide/migrate for instructions on how to migrate your code to TensorFlow v2.

# %% [markdown]
# ### Generate a TensorFlow Lite Model
#
# Convert the frozen graph into a TensorFlow Lite model, which is fully quantized for use with embedded devices.
#
# The following cell will also print the model size, which will be under 20 kilobytes.
#
# We download the dataset to use as a representative dataset for more thoughtful post training quantization.

# %%
model_settings = models.prepare_model_settings(
    len(input_data.prepare_words_list(WANTED_WORDS.split(','))),
    SAMPLE_RATE, CLIP_DURATION_MS, WINDOW_SIZE_MS,
    WINDOW_STRIDE, FEATURE_BIN_COUNT, PREPROCESS)
audio_processor = input_data.AudioProcessor(
    DATA_URL, DATASET_DIR,
    SILENT_PERCENTAGE, UNKNOWN_PERCENTAGE,
    WANTED_WORDS.split(','), VALIDATION_PERCENTAGE,
    TESTING_PERCENTAGE, model_settings, LOGS_DIR)

# %%
with tf.compat.v1.Session() as sess:

    converter = tf.lite.TFLiteConverter.from_saved_model(SAVED_MODEL)
    converter.optimizations = [tf.lite.Optimize.DEFAULT]
    converter.inference_input_type = tf.int8
    converter.inference_output_type = tf.int8

    def representative_dataset_gen():
        for i in range(100):
            data, _ = audio_processor.get_data(
                1, i, model_settings,
                BACKGROUND_FREQUENCY,
                BACKGROUND_VOLUME_RANGE,
                TIME_SHIFT_MS,
                'testing',
                sess
            )
            flattened = np.array(data.flatten(), dtype=np.float32).reshape(FLATTENED_SPECTROGRAM_SHAPE)
            yield [flattened]

    converter.representative_dataset = representative_dataset_gen


    quantized_tflite_model = converter.convert()

    # Save to file
    with open(MODEL_TFLITE, "wb") as f:
        f.write(quantized_tflite_model)

    print(f"Quantized model saved to {MODEL_TFLITE}, size: {len(quantized_tflite_model)} bytes")
# Out:
# Quantized model saved to models/model.tflite, size: 19176 bytes

# %% [markdown]
# ### Testing the accuracy after Quantization
#
# Verify that the model we've exported is still accurate, using the TF Lite Python API and our test set.

# %%
# Helper function to run inference
def run_tflite_inference_testSet(tflite_model_path, model_type="Float"):
  #
  # Load test data
  #
  np.random.seed(0) # set random seed for reproducible test results.
  with tf.Session() as sess:
  # with tf.compat.v1.Session() as sess: #replaces the above line for use with TF2.x
    test_data, test_labels = audio_processor.get_data(
        -1, 0, model_settings, BACKGROUND_FREQUENCY, BACKGROUND_VOLUME_RANGE,
        TIME_SHIFT_MS, 'testing', sess)
  test_data = np.expand_dims(test_data, axis=1).astype(np.float32)

  #
  # Initialize the interpreter
  #
  interpreter = tf.lite.Interpreter(tflite_model_path)
  interpreter.allocate_tensors()
  input_details = interpreter.get_input_details()[0]
  output_details = interpreter.get_output_details()[0]

  #
  # For quantized models, manually quantize the input data from float to integer
  #
  if model_type == "Quantized":
    input_scale, input_zero_point = input_details["quantization"]
    test_data = test_data / input_scale + input_zero_point
    test_data = test_data.astype(input_details["dtype"])

  #
  # Evaluate the predictions
  #
  correct_predictions = 0
  for i in range(len(test_data)):
    interpreter.set_tensor(input_details["index"], test_data[i])
    interpreter.invoke()
    output = interpreter.get_tensor(output_details["index"])[0]
    top_prediction = output.argmax()
    correct_predictions += (top_prediction == test_labels[i])

  print('%s model accuracy is %f%% (Number of test samples=%d)' % (
      model_type, (correct_predictions * 100) / len(test_data), len(test_data)))

# %%
# Compute float model accuracy
run_tflite_inference_testSet(FLOAT_MODEL_TFLITE)

# Compute quantized model accuracy
run_tflite_inference_testSet(MODEL_TFLITE, model_type='Quantized')
# Out:
# /usr/local/lib/python3.12/dist-packages/tensorflow/lite/python/interpreter.py:457: UserWarning:     Warning: tf.lite.Interpreter is deprecated and is scheduled for deletion in
#     TF 2.20. Please use the LiteRT interpreter from the ai_edge_litert package.
#     See the [migration guide](https://ai.google.dev/edge/litert/migration)
#     for details.
#
#   warnings.warn(_INTERPRETER_DELETION_WARNING)
# Float model accuracy is 92.394822% (Number of test samples=1236)
# Quantized model accuracy is 92.394822% (Number of test samples=1236)

# %% [markdown]
# # Testing the model with your own data!
# Now comes the fun part. It's time to test your model with your own realworld data. We'll proceed in the same way we tested the pre-trained model. Have fun!

# %% [markdown]
# ### Importing packages

# %%
# !pip install ffmpeg-python &> 0
from IPython.display import HTML, Audio
from google.colab.output import eval_js
from base64 import b64decode
import numpy as np
from scipy.io.wavfile import read as wav_read
import io
import ffmpeg
# !pip install librosa
import librosa
import scipy.io.wavfile
# !git clone https://github.com/petewarden/extract_loudest_section.git
# !make -C extract_loudest_section/
print("Packages Imported, Extract_Loudest_Section Built")
# Out:
# Requirement already satisfied: librosa in /usr/local/lib/python3.12/dist-packages (0.11.0)
# Requirement already satisfied: audioread>=2.1.9 in /usr/local/lib/python3.12/dist-packages (from librosa) (3.1.0)
# Requirement already satisfied: numba>=0.51.0 in /usr/local/lib/python3.12/dist-packages (from librosa) (0.60.0)
# Requirement already satisfied: numpy>=1.22.3 in /usr/local/lib/python3.12/dist-packages (from librosa) (2.0.2)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from librosa) (1.16.3)
# Requirement already satisfied: scikit-learn>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from librosa) (1.6.1)
# Requirement already satisfied: joblib>=1.0 in /usr/local/lib/python3.12/dist-packages (from librosa) (1.5.3)
# Requirement already satisfied: decorator>=4.3.0 in /usr/local/lib/python3.12/dist-packages (from librosa) (4.4.2)
# Requirement already satisfied: soundfile>=0.12.1 in /usr/local/lib/python3.12/dist-packages (from librosa) (0.13.1)
# Requirement already satisfied: pooch>=1.1 in /usr/local/lib/python3.12/dist-packages (from librosa) (1.9.0)
# Requirement already satisfied: soxr>=0.3.2 in /usr/local/lib/python3.12/dist-packages (from librosa) (1.0.0)
# Requirement already satisfied: typing_extensions>=4.1.1 in /usr/local/lib/python3.12/dist-packages (from librosa) (4.15.0)
# Requirement already satisfied: lazy_loader>=0.1 in /usr/local/lib/python3.12/dist-packages (from librosa) (0.5)
# Requirement already satisfied: msgpack>=1.0 in /usr/local/lib/python3.12/dist-packages (from librosa) (1.1.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from lazy_loader>=0.1->librosa) (26.0)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.12/dist-packages (from numba>=0.51.0->librosa) (0.43.0)
# Requirement already satisfied: platformdirs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from pooch>=1.1->librosa) (4.9.4)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.12/dist-packages (from pooch>=1.1->librosa) (2.32.4)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=1.1.0->librosa) (3.6.0)
# Requirement already satisfied: cffi>=1.0 in /usr/local/lib/python3.12/dist-packages (from soundfile>=0.12.1->librosa) (2.0.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi>=1.0->soundfile>=0.12.1->librosa) (3.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.19.0->pooch>=1.1->librosa) (3.4.6)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.19.0->pooch>=1.1->librosa) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.19.0->pooch>=1.1->librosa) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.19.0->pooch>=1.1->librosa) (2026.2.25)
# Cloning into 'extract_loudest_section'...
# remote: Enumerating objects: 58, done.
# remote: Total 58 (delta 0), reused 0 (delta 0), pack-reused 58 (from 1)
# Receiving objects: 100% (58/58), 49.00 KiB | 2.88 MiB/s, done.
# Resolving deltas: 100% (17/17), done.
# make: Entering directory '/content/extract_loudest_section'
# gcc --std=c++11 -O3 -DNDEBUG -I. -c main.cc -o /tmp/extract_loudest_section//gen/obj/./main.o
# gcc --std=c++11 -O3 -DNDEBUG -I. -c status.cc -o /tmp/extract_loudest_section//gen/obj/./status.o
# gcc --std=c++11 -O3 -DNDEBUG -I. -c wav_io.cc -o /tmp/extract_loudest_section//gen/obj/./wav_io.o
# gcc  -I. \
# -o /tmp/extract_loudest_section//gen/bin//extract_loudest_section /tmp/extract_loudest_section//gen/obj/./main.o /tmp/extract_loudest_section//gen/obj/./status.o /tmp/extract_loudest_section//gen/obj/./wav_io.o \
#  -lstdc++ -lm
# make: Leaving directory '/content/extract_loudest_section'
# Packages Imported, Extract_Loudest_Section Built

# %% [markdown]
# ### Define the helper function to run inference

# %%
# Helper function to run inference (on a single input this time)
# Note: this also includes additional manual pre-processing
TF_SESS = tf.compat.v1.InteractiveSession()
def run_tflite_inference_singleFile(tflite_model_path, custom_audio, sr_custom_audio, model_type="Float"):
  #
  # Preprocess the sample to get the features we pass to the model
  #
  # First re-sample to the needed rate (and convert to mono if needed)
  custom_audio_resampled = librosa.resample(y = librosa.to_mono(np.float64(custom_audio)), orig_sr = sr_custom_audio, target_sr = SAMPLE_RATE)
  # Then extract the loudest one second
  scipy.io.wavfile.write('custom_audio.wav', SAMPLE_RATE, np.int16(custom_audio_resampled))
  # !/tmp/extract_loudest_section/gen/bin/extract_loudest_section custom_audio.wav ./trimmed
  # Finally pass it through the TFLiteMicro preprocessor to produce the
  # spectrogram/MFCC input that the model expects
  custom_model_settings = models.prepare_model_settings(
      0, SAMPLE_RATE, CLIP_DURATION_MS, WINDOW_SIZE_MS,
      WINDOW_STRIDE, FEATURE_BIN_COUNT, PREPROCESS)
  custom_audio_processor = input_data.AudioProcessor(None, None, 0, 0, '', 0, 0,
                                                    model_settings, None)
  custom_audio_preprocessed = custom_audio_processor.get_features_for_wav(
                                        'trimmed/custom_audio.wav', model_settings, TF_SESS)
  # Reshape the output into a 1,1960 matrix as that is what the model expects
  custom_audio_input = custom_audio_preprocessed[0].flatten()
  test_data = np.reshape(custom_audio_input,(1,len(custom_audio_input)))

  #
  # Initialize the interpreter
  #
  interpreter = tf.lite.Interpreter(tflite_model_path)
  interpreter.allocate_tensors()
  input_details = interpreter.get_input_details()[0]
  output_details = interpreter.get_output_details()[0]

  #
  # For quantized models, manually quantize the input data from float to integer
  #
  if model_type == "Quantized":
    input_scale, input_zero_point = input_details["quantization"]
    test_data = test_data / input_scale + input_zero_point
    test_data = test_data.astype(input_details["dtype"])

  #
  # Run the interpreter
  #
  interpreter.set_tensor(input_details["index"], test_data)
  interpreter.invoke()
  output = interpreter.get_tensor(output_details["index"])[0]
  top_prediction = output.argmax()

  #
  # Translate the output
  #
  top_prediction_str = ''
  if top_prediction >= 2:
    top_prediction_str = WANTED_WORDS.split(',')[top_prediction-2]
  elif top_prediction == 0:
    top_prediction_str = 'silence'
  else:
    top_prediction_str = 'unknown'

  print('%s model guessed the value to be %s' % (model_type, top_prediction_str))

# %% [markdown]
# ### Define the audio importing function
# Adapted from: https://ricardodeazambuja.com/deep_learning/2019/03/09/audio_and_video_google_colab/ and https://colab.research.google.com/drive/1Z6VIRZ_sX314hyev3Gm5gBqvm1wQVo-a#scrollTo=RtMcXr3o6gxN

# %%
AUDIO_HTML = """
<script>
var my_div = document.createElement("DIV");
var my_p = document.createElement("P");
var my_btn = document.createElement("BUTTON");
var t = document.createTextNode("Press to start recording");

my_btn.appendChild(t);
//my_p.appendChild(my_btn);
my_div.appendChild(my_btn);
document.body.appendChild(my_div);

var base64data = 0;
var reader;
var recorder, gumStream;
var recordButton = my_btn;

var handleSuccess = function(stream) {
  gumStream = stream;
  var options = {
    //bitsPerSecond: 8000, //chrome seems to ignore, always 48k
    mimeType : 'audio/webm;codecs=opus'
    //mimeType : 'audio/webm;codecs=pcm'
  };
  //recorder = new MediaRecorder(stream, options);
  recorder = new MediaRecorder(stream);
  recorder.ondataavailable = function(e) {
    var url = URL.createObjectURL(e.data);
    var preview = document.createElement('audio');
    preview.controls = true;
    preview.src = url;
    document.body.appendChild(preview);

    reader = new FileReader();
    reader.readAsDataURL(e.data);
    reader.onloadend = function() {
      base64data = reader.result;
      //console.log("Inside FileReader:" + base64data);
    }
  };
  recorder.start();
  };

recordButton.innerText = "Recording... press to stop";

navigator.mediaDevices.getUserMedia({audio: true}).then(handleSuccess);


function toggleRecording() {
  if (recorder && recorder.state == "recording") {
      recorder.stop();
      gumStream.getAudioTracks()[0].stop();
      recordButton.innerText = "Saving the recording... pls wait!"
  }
}

// https://stackoverflow.com/a/951057
function sleep(ms) {
  return new Promise(resolve => setTimeout(resolve, ms));
}

var data = new Promise(resolve=>{
//recordButton.addEventListener("click", toggleRecording);
recordButton.onclick = ()=>{
toggleRecording()

sleep(2000).then(() => {
  // wait 2000ms for the data to be available...
  // ideally this should use something like await...
  //console.log("Inside data:" + base64data)
  resolve(base64data.toString())

});

}
});

</script>
"""

def get_audio():
  display(HTML(AUDIO_HTML))
  data = eval_js("data")
  binary = b64decode(data.split(',')[1])

  process = (ffmpeg
    .input('pipe:0')
    .output('pipe:1', format='wav', ac='1')
    .run_async(pipe_stdin=True, pipe_stdout=True, pipe_stderr=True, quiet=True, overwrite_output=True)
  )
  output, err = process.communicate(input=binary)

  riff_chunk_size = len(output) - 8
  # Break up the chunk size into four bytes, held in b.
  q = riff_chunk_size
  b = []
  for i in range(4):
      q, r = divmod(q, 256)
      b.append(r)

  # Replace bytes 4:8 in proc.stdout with the actual size of the RIFF chunk.
  riff = output[:4] + bytes(b) + output[8:]

  sr, audio = wav_read(io.BytesIO(riff))

  return audio, sr
print("Chrome Audio Recorder Defined")
# Out:
# Chrome Audio Recorder Defined

# %% [markdown]
# ### Record your own audio and test the model!
# After you run the record cell wait for the stop button to appear then start recording and then press the button to stop the recording once you have said the word!

# %%
custom_audio, sr_custom_audio = get_audio()
print("DONE")
# Out:
# <script>
# var my_div = document.createElement("DIV");
# var my_p = document.createElement("P");
# var my_btn = document.createElement("BUTTON");
# var t = document.createTextNode("Press to start recording");
#
# my_btn.appendChild(t);
# //my_p.appendChild(my_btn);
# my_div.appendChild(my_btn);
# document.body.appendChild(my_div);
#
# var base64data = 0;
# var reader;
# var recorder, gumStream;
# var recordButton = my_btn;
#
# var handleSuccess = function(stream) {
#   gumStream = stream;
#   var options = {
#     //bitsPerSecond: 8000, //chrome seems to ignore, always 48k
#     mimeType : 'audio/webm;codecs=opus'
#     //mimeType : 'audio/webm;codecs=pcm'
#   };
#   //recorder = new MediaRecorder(stream, options);
#   recorder = new MediaRecorder(stream);
#   recorder.ondataavailable = function(e) {
#     var url = URL.createObjectURL(e.data);
#     var preview = document.createElement('audio');
#     preview.controls = true;
#     preview.src = url;
#     document.body.appendChild(preview);
#
#     reader = new FileReader();
#     reader.readAsDataURL(e.data);
#     reader.onloadend = function() {
#       base64data = reader.result;
#       //console.log("Inside FileReader:" + base64data);
#     }
#   };
#   recorder.start();
#   };
#
# recordButton.innerText = "Recording... press to stop";
#
# navigator.mediaDevices.getUserMedia({audio: true}).then(handleSuccess);
#
#
# function toggleRecording() {
#   if (recorder && recorder.state == "recording") {
#       recorder.stop();
#       gumStream.getAudioTracks()[0].stop();
#       recordButton.innerText = "Saving the recording... pls wait!"
#   }
# }
#
# // https://stackoverflow.com/a/951057
# function sleep(ms) {
#   return new Promise(resolve => setTimeout(resolve, ms));
# }
#
# var data = new Promise(resolve=>{
# //recordButton.addEventListener("click", toggleRecording);
# recordButton.onclick = ()=>{
# toggleRecording()
#
# sleep(2000).then(() => {
#   // wait 2000ms for the data to be available...
#   // ideally this should use something like await...
#   //console.log("Inside data:" + base64data)
#   resolve(base64data.toString())
#
# });
#
# }
# });
#
# </script>

# %%
# Then test the model
run_tflite_inference_singleFile(MODEL_TFLITE, custom_audio, sr_custom_audio, model_type="Quantized")
